# %%
import numpy as np
import pandas as pd
import json

from statsmodels.stats.inter_rater import fleiss_kappa, aggregate_raters
import matplotlib.pyplot as plt

# %%
# read tsv with headers
with open("./exports/crowd_data.tsv", "r") as f:
    crowd_df = pd.read_csv(f, sep="\t", index_col="AssignmentId")
    crowd_df = crowd_df.sort_values(by=["HITId", "WorkerId"])

crowd_df
# Out:
#               HITId HITTypeId                                 Title Reward  \
# AssignmentId
# 4                 1       7QT  Is this triple correct or incorrect?  $0.50
# 1                 1       7QT  Is this triple correct or incorrect?  $0.50
# 2                 1       7QT  Is this triple correct or incorrect?  $0.50
# 5                 1       7QT  Is this triple correct or incorrect?  $0.50
# 3                 1       7QT  Is this triple correct or incorrect?  $0.50
# ...             ...       ...                                   ...    ...
# 301              61       9QT  Is this triple correct or incorrect?  $0.50
# 303              61       9QT  Is this triple correct or incorrect?  $0.50
# 302              61       9QT  Is this triple correct or incorrect?  $0.50
# 305              61       9QT  Is this triple correct or incorrect?  $0.50
# 304              61       9QT  Is this triple correct or incorrect?  $0.50
#
#                  WorkerId AssignmentStatus  WorkTimeInSeconds  \
# AssignmentId
# 4               1726JMZQW        Submitted                 80
# 1             2133ICYWE97        Submitted                 60
# 2             2133U7HKDLO        Submitted                 40
# 5             2134U7HKDMM        Submitted                  2
# 3             928UJANWZ12        Submitted                 50
# ...                   ...              ...                ...
# 301             AALKMII97        Submitted                240
# 303            GGUI83657S        Submitted                120
# 302             HHCKW1111        Submitted                200
# 305           QZAHIFT8263        Submitted                  2
# 304           WWHL098SA43        Submitted                 10
#
#              LifetimeApprovalRate     Input1ID   Input2ID   Input3ID  \
# AssignmentId
# 4                             70%    wd:Q11621  wdt:P2142  792910554
# 1                             99%    wd:Q11621  wdt:P2142  792910554
# 2                             40%    wd:Q11621  wdt:P2142  792910554
# 5                             70%    wd:Q11621  wdt:P2142  792910554
# 3                             98%    wd:Q11621  wdt:P2142  792910554
# ...                           ...          ...        ...        ...
# 301                           98%  wd:Q1288004  wdt:P1412  wd:Q13330
# 303                           85%  wd:Q1288004  wdt:P1412  wd:Q13330
# 302                           80%  wd:Q1288004  wdt:P1412  wd:Q13330
# 305                           40%  wd:Q1288004  wdt:P1412  wd:Q13330
# 304                           69%  wd:Q1288004  wdt:P1412  wd:Q13330
#
#               AnswerID AnswerLabel FixPosition FixValue
# AssignmentId
# 4                  1.0     CORRECT         NaN      NaN
# 1                  1.0     CORRECT         NaN      NaN
# 2                  1.0     CORRECT         yes      yes
# 5                  1.0     CORRECT         NaN      NaN
# 3                  2.0   INCORRECT         NaN      NaN
# ...                ...         ...         ...      ...
# 301                2.0   INCORRECT      Object    Q1860
# 303                1.0     CORRECT         NaN      NaN
# 302                1.0     CORRECT         NaN      NaN
# 305                2.0   INCORRECT         100      100
# 304                2.0   INCORRECT         NaN      NaN
#
# [305 rows x 15 columns]

# %%
crowd_df = crowd_df.drop(columns=["Title", "Reward", "AssignmentStatus"])
crowd_df
# Out:
#               HITId HITTypeId     WorkerId  WorkTimeInSeconds  \
# AssignmentId
# 4                 1       7QT    1726JMZQW                 80
# 1                 1       7QT  2133ICYWE97                 60
# 2                 1       7QT  2133U7HKDLO                 40
# 5                 1       7QT  2134U7HKDMM                  2
# 3                 1       7QT  928UJANWZ12                 50
# ...             ...       ...          ...                ...
# 301              61       9QT    AALKMII97                240
# 303              61       9QT   GGUI83657S                120
# 302              61       9QT    HHCKW1111                200
# 305              61       9QT  QZAHIFT8263                  2
# 304              61       9QT  WWHL098SA43                 10
#
#              LifetimeApprovalRate     Input1ID   Input2ID   Input3ID  \
# AssignmentId
# 4                             70%    wd:Q11621  wdt:P2142  792910554
# 1                             99%    wd:Q11621  wdt:P2142  792910554
# 2                             40%    wd:Q11621  wdt:P2142  792910554
# 5                             70%    wd:Q11621  wdt:P2142  792910554
# 3                             98%    wd:Q11621  wdt:P2142  792910554
# ...                           ...          ...        ...        ...
# 301                           98%  wd:Q1288004  wdt:P1412  wd:Q13330
# 303                           85%  wd:Q1288004  wdt:P1412  wd:Q13330
# 302                           80%  wd:Q1288004  wdt:P1412  wd:Q13330
# 305                           40%  wd:Q1288004  wdt:P1412  wd:Q13330
# 304                           69%  wd:Q1288004  wdt:P1412  wd:Q13330
#
#               AnswerID AnswerLabel FixPosition FixValue
# AssignmentId
# 4                  1.0     CORRECT         NaN      NaN
# 1                  1.0     CORRECT         NaN      NaN
# 2                  1.0     CORRECT         yes      yes
# 5                  1.0     CORRECT         NaN      NaN
# 3                  2.0   INCORRECT         NaN      NaN
# ...                ...         ...         ...      ...
# 301                2.0   INCORRECT      Object    Q1860
# 303                1.0     CORRECT         NaN      NaN
# 302                1.0     CORRECT         NaN      NaN
# 305                2.0   INCORRECT         100      100
# 304                2.0   INCORRECT         NaN      NaN
#
# [305 rows x 12 columns]

# %%
crowd_df['LifetimeApprovalRate'] = crowd_df['LifetimeApprovalRate'].astype(str).str.rstrip('%').astype(float)

median_rate = crowd_df['LifetimeApprovalRate'].median()

correction = 0
crowd_df = crowd_df[(crowd_df['LifetimeApprovalRate'] >= median_rate - correction)]

print(f"Median lifetime approval rate: {int(median_rate)}%")

crowd_df
# Out:
# Median lifetime approval rate: 80%
#               HITId HITTypeId     WorkerId  WorkTimeInSeconds  \
# AssignmentId
# 1                 1       7QT  2133ICYWE97                 60
# 3                 1       7QT  928UJANWZ12                 50
# 7                 2       7QT  2133ICYWE97                120
# 8                 2       7QT  928UJANWZ12                 60
# 11                3       7QT  2133ICYWE97                140
# ...             ...       ...          ...                ...
# 298              60       9QT   GGUI83657S                120
# 297              60       9QT    HHCKW1111                200
# 301              61       9QT    AALKMII97                240
# 303              61       9QT   GGUI83657S                120
# 302              61       9QT    HHCKW1111                200
#
#               LifetimeApprovalRate      Input1ID   Input2ID    Input3ID  \
# AssignmentId
# 1                             99.0     wd:Q11621  wdt:P2142   792910554
# 3                             98.0     wd:Q11621  wdt:P2142   792910554
# 7                             99.0    wd:Q603545  wdt:P2142     4300000
# 8                             98.0    wd:Q603545  wdt:P2142     4300000
# 11                            99.0  wd:Q16911843   wdt:P577  2014-01-18
# ...                            ...           ...        ...         ...
# 298                           85.0  wd:Q21060270    wdt:P27     wd:Q916
# 297                           80.0  wd:Q21060270    wdt:P27     wd:Q916
# 301                           98.0   wd:Q1288004  wdt:P1412   wd:Q13330
# 303                           85.0   wd:Q1288004  wdt:P1412   wd:Q13330
# 302                           80.0   wd:Q1288004  wdt:P1412   wd:Q13330
#
#               AnswerID AnswerLabel FixPosition    FixValue
# AssignmentId
# 1                  1.0     CORRECT         NaN         NaN
# 3                  2.0   INCORRECT         NaN         NaN
# 7                  1.0     CORRECT         NaN         NaN
# 8                  1.0     CORRECT         NaN         NaN
# 11                 2.0   INCORRECT      Object  2014-02-18
# ...                ...         ...         ...         ...
# 298                1.0     CORRECT         NaN         NaN
# 297                1.0     CORRECT         NaN         NaN
# 301                2.0   INCORRECT      Object       Q1860
# 303                1.0     CORRECT         NaN         NaN
# 302                1.0     CORRECT         NaN         NaN
#
# [162 rows x 12 columns]

# %%
median_rate = crowd_df['WorkTimeInSeconds'].median()

correction = 0
crowd_df = crowd_df[(crowd_df['WorkTimeInSeconds'] >= median_rate - correction)]

print(f"Median work time in seconds: {int(median_rate)}s")
crowd_df
# Out:
# Median work time in seconds: 200s
#               HITId HITTypeId     WorkerId  WorkTimeInSeconds  \
# AssignmentId
# 17                4       7QT  928UJANWZ12                240
# 23                5       7QT  928UJANWZ12                240
# 37                8       7QT  928UJANWZ12                240
# 52               11       7QT  928UJANWZ12                240
# 57               12       7QT  928UJANWZ12                240
# ...             ...       ...          ...                ...
# 292              59       9QT    HHCKW1111                200
# 296              60       9QT    AALKMII97                240
# 297              60       9QT    HHCKW1111                200
# 301              61       9QT    AALKMII97                240
# 302              61       9QT    HHCKW1111                200
#
#               LifetimeApprovalRate       Input1ID                 Input2ID  \
# AssignmentId
# 17                            98.0     wd:Q132863                wdt:P2142
# 23                            98.0    wd:Q1628022                 wdt:P577
# 37                            98.0     wd:Q217010                wdt:P2142
# 52                            98.0    wd:Q1339195  ddis:indirectSubclassOf
# 57                            98.0  wd:Q104649845  ddis:indirectSubclassOf
# ...                            ...            ...                      ...
# 292                           80.0    wd:Q1893555                 wdt:P272
# 296                           98.0   wd:Q21060270                  wdt:P27
# 297                           80.0   wd:Q21060270                  wdt:P27
# 301                           98.0    wd:Q1288004                wdt:P1412
# 302                           80.0    wd:Q1288004                wdt:P1412
#
#                   Input3ID  AnswerID AnswerLabel FixPosition   FixValue
# AssignmentId
# 17               969023261       2.0   INCORRECT         NaN        NaN
# 23              1951-01-01       1.0     CORRECT         NaN        NaN
# 37               698491347       2.0   INCORRECT      Object  698491348
# 52            wd:Q27096213       2.0   INCORRECT      Object     wd:Q72
# 57               wd:Q43229       1.0     CORRECT         NaN        NaN
# ...                    ...       ...         ...         ...        ...
# 292           wd:Q48784114       2.0   INCORRECT      Object   Q7488442
# 296                wd:Q916       2.0   INCORRECT      Object       Q884
# 297                wd:Q916       1.0     CORRECT         NaN        NaN
# 301              wd:Q13330       2.0   INCORRECT      Object      Q1860
# 302              wd:Q13330       1.0     CORRECT         NaN        NaN
#
# [85 rows x 12 columns]

# %%
crowd_df = crowd_df.drop(columns=["WorkTimeInSeconds", "LifetimeApprovalRate"])

# %%
filtered_df = crowd_df.groupby("HITId").filter(
    lambda group: group[group["AnswerLabel"] == "INCORRECT"].shape[0] >
                  group[group["AnswerLabel"] == "CORRECT"].shape[0]
)
filtered_df
# Out:
#               HITId HITTypeId     WorkerId      Input1ID  \
# AssignmentId
# 17                4       7QT  928UJANWZ12    wd:Q132863
# 37                8       7QT  928UJANWZ12    wd:Q217010
# 52               11       7QT  928UJANWZ12   wd:Q1339195
# 67               14       7QT  928UJANWZ12      wd:Q1004
# 97               20       7QT  928UJANWZ12  wd:Q15239622
# 106              22       8QT    AALKMII98   wd:Q1720855
# 111              23       8QT    AALKMII98    wd:Q598752
# 112              23       8QT    HHCKW1111    wd:Q598752
# 127              26       8QT    AALKMII98   wd:Q1410031
# 126              26       8QT    HHCKW1111   wd:Q1410031
# 141              29       8QT    AALKMII98    wd:Q639070
# 142              29       8QT    HHCKW1111    wd:Q639070
# 166              34       8QT    AALKMII98   wd:Q1039395
# 167              34       8QT    HHCKW1111   wd:Q1039395
# 191              39       8QT    AALKMII98    wd:Q814781
# 201              41       8QT    AALKMII98   wd:Q1123629
# 202              41       8QT    HHCKW1111   wd:Q1123629
# 211              43       9QT    AALKMII97    wd:Q610633
# 212              43       9QT    HHCKW1111    wd:Q610633
# 216              44       9QT    AALKMII97   wd:Q2188914
# 217              44       9QT    HHCKW1111   wd:Q2188914
# 226              46       9QT    AALKMII97    wd:Q209538
# 227              46       9QT    HHCKW1111    wd:Q209538
# 231              47       9QT    AALKMII97  wd:Q31202708
# 232              47       9QT    HHCKW1111  wd:Q31202708
# 286              58       9QT    AALKMII97    wd:Q943992
# 290              58       9QT    HHCKW1111    wd:Q943992
#
#                              Input2ID      Input3ID  AnswerID AnswerLabel  \
# AssignmentId
# 17                          wdt:P2142     969023261       2.0   INCORRECT
# 37                          wdt:P2142     698491347       2.0   INCORRECT
# 52            ddis:indirectSubclassOf  wd:Q27096213       2.0   INCORRECT
# 67            ddis:indirectSubclassOf  wd:Q47461344       2.0   INCORRECT
# 97            ddis:indirectSubclassOf  wd:Q27096213       2.0   INCORRECT
# 106                          wdt:P577    2010-10-01       2.0   INCORRECT
# 111                          wdt:P577    2001-01-01       2.0   INCORRECT
# 112                          wdt:P577    2001-01-01       2.0   INCORRECT
# 127                          wdt:P577    2010-10-01       2.0   INCORRECT
# 126                          wdt:P577    2010-10-01       2.0   INCORRECT
# 141                          wdt:P161   wd:Q2865083       2.0   INCORRECT
# 142                          wdt:P161   wd:Q2865083       2.0   INCORRECT
# 166                          wdt:P161  wd:Q17386547       2.0   INCORRECT
# 167                          wdt:P161  wd:Q17386547       2.0   INCORRECT
# 191                         wdt:.P344  wd:Q40087803       2.0   INCORRECT
# 201                          wdt:P725    wd:Q211040       2.0   INCORRECT
# 202                          wdt:P725    wd:Q211040       2.0   INCORRECT
# 211                         wdt:P2554   wd:Q1700810       2.0   INCORRECT
# 212                         wdt:P2554   wd:Q1700810       2.0   INCORRECT
# 216                          wdt:P161   wd:Q2416526       2.0   INCORRECT
# 217                          wdt:P161   wd:Q2416526       2.0   INCORRECT
# 226                         wdt:P3650  wd:Q28732983       2.0   INCORRECT
# 227                         wdt:P3650  wd:Q28732983       2.0   INCORRECT
# 231                         wdt:P3092   wd:Q4805527       2.0   INCORRECT
# 232                         wdt:P3092   wd:Q4805527       2.0   INCORRECT
# 286                          wdt:P161    wd:Q160432       2.0   INCORRECT
# 290                          wdt:P161    wd:Q160432       2.0   INCORRECT
#
#              FixPosition    FixValue
# AssignmentId
# 17                   NaN         NaN
# 37                Object   698491348
# 52                Object      wd:Q72
# 67                   NaN         NaN
# 97                   NaN         NaN
# 106               Object  2010-01-01
# 111               Object  2011-01-01
# 112               Object  2011-01-01
# 127               Object  2011-01-01
# 126               Object  2011-01-01
# 141               Object    Q5423258
# 142               Object    Q5423258
# 166              Subject     Q908556
# 167              Subject     Q908556
# 191              Subject   Q27703272
# 201            Predicate        P161
# 202            Predicate        P161
# 211            Predicate         P58
# 212            Predicate         P58
# 216               Object   Q17350908
# 217               Object   Q17350908
# 226               Object         NaN
# 227               Object   Q28732985
# 231            Predicate         P58
# 232            Predicate         P58
# 286               Object    Q7360827
# 290               Object         NaN

# %%
json_files = ["./exports/people_db.json", "./exports/movie_db.json"]
merged_data = {
    k.split("/")[-1]: v
    for file_path in json_files
    for k, v in json.load(open(file_path, 'r')).items()
}

with open("./exports/predicate_db.json", 'r') as f:
    # Reversed index
    merged_data.update({v.split("/")[-1]: k for k, v in json.load(f).items()})

def set_label(value, required=True):
    value = str(value)
    if "/" in value:
        value = value.split("/")[-1]
    elif ":" in value:
        value = value.split(":")[-1]
    return merged_data.get(value, np.nan if required else value)

for column in ["Input1ID", "Input2ID"]:
    filtered_df[column] = filtered_df[column].apply(set_label, required=True)

for column in ["Input3ID", "FixValue"]:
    filtered_df[column] = filtered_df[column].apply(set_label, required=False)


filtered_df = filtered_df.dropna(subset=["Input1ID", "Input2ID", "Input3ID"])

filtered_df
# Out:
#               HITId HITTypeId     WorkerId                   Input1ID  \
# AssignmentId
# 17                4       7QT  928UJANWZ12               finding nemo
# 37                8       7QT  928UJANWZ12  the twilight saga eclipse
# 106              22       8QT    AALKMII98                     kaboom
# 111              23       8QT    AALKMII98                 like crazy
# 112              23       8QT    HHCKW1111                 like crazy
# 127              26       8QT    AALKMII98            tom meets zizou
# 126              26       8QT    HHCKW1111            tom meets zizou
# 141              29       8QT    AALKMII98          magic carpet ride
# 142              29       8QT    HHCKW1111          magic carpet ride
# 166              34       8QT    AALKMII98    martial arts of shaolin
# 167              34       8QT    HHCKW1111    martial arts of shaolin
# 201              41       8QT    AALKMII98        conan the barbarian
# 202              41       8QT    HHCKW1111        conan the barbarian
# 211              43       9QT    AALKMII97                     eskimo
# 212              43       9QT    HHCKW1111                     eskimo
# 216              44       9QT    AALKMII97              a happy event
# 217              44       9QT    HHCKW1111              a happy event
# 226              46       9QT    AALKMII97                 iron man 3
# 227              46       9QT    HHCKW1111                 iron man 3
# 231              47       9QT    AALKMII97           top gun maverick
# 232              47       9QT    HHCKW1111           top gun maverick
# 286              58       9QT    AALKMII97       a night at the opera
# 290              58       9QT    HHCKW1111       a night at the opera
#
#                          Input2ID          Input3ID  AnswerID AnswerLabel  \
# AssignmentId
# 17                     box office         969023261       2.0   INCORRECT
# 37                     box office         698491347       2.0   INCORRECT
# 106              publication date        2010-10-01       2.0   INCORRECT
# 111              publication date        2001-01-01       2.0   INCORRECT
# 112              publication date        2001-01-01       2.0   INCORRECT
# 127              publication date        2010-10-01       2.0   INCORRECT
# 126              publication date        2010-10-01       2.0   INCORRECT
# 141                   cast member     arthur dupont       2.0   INCORRECT
# 142                   cast member     arthur dupont       2.0   INCORRECT
# 166                   cast member  peter breitmayer       2.0   INCORRECT
# 167                   cast member  peter breitmayer       2.0   INCORRECT
# 201                   voice actor      rose mcgowan       2.0   INCORRECT
# 202                   voice actor      rose mcgowan       2.0   INCORRECT
# 211           production designer    john lee mahin       2.0   INCORRECT
# 212           production designer    john lee mahin       2.0   INCORRECT
# 216                   cast member     theis schmidt       2.0   INCORRECT
# 217                   cast member     theis schmidt       2.0   INCORRECT
# 226               jmk film rating         Q28732983       2.0   INCORRECT
# 227               jmk film rating         Q28732983       2.0   INCORRECT
# 231              film crew member     ashley miller       2.0   INCORRECT
# 232              film crew member     ashley miller       2.0   INCORRECT
# 286                   cast member          jude law       2.0   INCORRECT
# 290                   cast member          jude law       2.0   INCORRECT
#
#              FixPosition         FixValue
# AssignmentId
# 17                   NaN              nan
# 37                Object        698491348
# 106               Object       2010-01-01
# 111               Object       2011-01-01
# 112               Object       2011-01-01
# 127               Object       2011-01-01
# 126               Object       2011-01-01
# 141               Object        ezgi mola
# 142               Object        ezgi mola
# 166              Subject  horrible bosses
# 167              Subject  horrible bosses
# 201            Predicate      cast member
# 202            Predicate      cast member
# 211            Predicate     screenwriter
# 212            Predicate     screenwriter
# 216               Object     erika sainte
# 217               Object     erika sainte
# 226               Object              nan
# 227               Object        Q28732985
# 231            Predicate     screenwriter
# 232            Predicate     screenwriter
# 286               Object      rolfe sedan
# 290               Object              nan

# %%
duplicate_answers = crowd_df[crowd_df.duplicated(subset=["WorkerId", "HITId"], keep=False)]
duplicate_summary = duplicate_answers.groupby(["WorkerId", "HITId"]).size().reset_index(name="Duplicate_Count")

if not duplicate_summary.empty:
    print("Workers who answered the same question more than once:")
else:
    print("No workers answered the same question more than once.")
# Out:
# No workers answered the same question more than once.

# %%
result = (
    filtered_df.groupby(["Input1ID", "Input2ID", "Input3ID"])
    .agg(
        Votes_CORRECT=("AnswerLabel", lambda x: (x == "CORRECT").sum()),
        Votes_INCORRECT=("AnswerLabel", lambda x: (x == "INCORRECT").sum()),
        Corrections_Subject=("FixValue", lambda x: x[filtered_df["FixPosition"] == "Subject"].tolist()),
        Corrections_Predicate=("FixValue", lambda x: x[filtered_df["FixPosition"] == "Predicate"].tolist()),
        Corrections_Object=("FixValue", lambda x: x[filtered_df["FixPosition"] == "Object"].tolist()),
    )
    .reset_index()
)

def ensure_single_value(corrections):
    unique_values = list(set([v for v in corrections if pd.notna(v) and v != "nan"]))
    if len(unique_values) > 1:
        raise ValueError(f"Multiple values found where a single value is expected: {unique_values}")
    return unique_values[0] if unique_values else np.nan  # Return the single value or None if the list is empty

# Apply the function to ensure a single value per correction
result["Corrections_Subject"] = result["Corrections_Subject"].apply(ensure_single_value)
result["Corrections_Predicate"] = result["Corrections_Predicate"].apply(ensure_single_value)
result["Corrections_Object"] = result["Corrections_Object"].apply(ensure_single_value)

result
# Out:
#                      Input1ID             Input2ID          Input3ID  \
# 0               a happy event          cast member     theis schmidt
# 1        a night at the opera          cast member          jude law
# 2         conan the barbarian          voice actor      rose mcgowan
# 3                      eskimo  production designer    john lee mahin
# 4                finding nemo           box office         969023261
# 5                  iron man 3      jmk film rating         Q28732983
# 6                      kaboom     publication date        2010-10-01
# 7                  like crazy     publication date        2001-01-01
# 8           magic carpet ride          cast member     arthur dupont
# 9     martial arts of shaolin          cast member  peter breitmayer
# 10  the twilight saga eclipse           box office         698491347
# 11            tom meets zizou     publication date        2010-10-01
# 12           top gun maverick     film crew member     ashley miller
#
#     Votes_CORRECT  Votes_INCORRECT Corrections_Subject Corrections_Predicate  \
# 0               0                2                 NaN                   NaN
# 1               0                2                 NaN                   NaN
# 2               0                2                 NaN           cast member
# 3               0                2                 NaN          screenwriter
# 4               0                1                 NaN                   NaN
# 5               0                2                 NaN                   NaN
# 6               0                1                 NaN                   NaN
# 7               0                2                 NaN                   NaN
# 8               0                2                 NaN                   NaN
# 9               0                2     horrible bosses                   NaN
# 10              0                1                 NaN                   NaN
# 11              0                2                 NaN                   NaN
# 12              0                2                 NaN          screenwriter
#
#    Corrections_Object
# 0        erika sainte
# 1         rolfe sedan
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5           Q28732985
# 6          2010-01-01
# 7          2011-01-01
# 8           ezgi mola
# 9                 NaN
# 10          698491348
# 11         2011-01-01
# 12                NaN

# %%
result.dropna(subset=["Corrections_Subject", "Corrections_Predicate", "Corrections_Object"])
result
# Out:
#                      Input1ID             Input2ID          Input3ID  \
# 0               a happy event          cast member     theis schmidt
# 1        a night at the opera          cast member          jude law
# 2         conan the barbarian          voice actor      rose mcgowan
# 3                      eskimo  production designer    john lee mahin
# 4                finding nemo           box office         969023261
# 5                  iron man 3      jmk film rating         Q28732983
# 6                      kaboom     publication date        2010-10-01
# 7                  like crazy     publication date        2001-01-01
# 8           magic carpet ride          cast member     arthur dupont
# 9     martial arts of shaolin          cast member  peter breitmayer
# 10  the twilight saga eclipse           box office         698491347
# 11            tom meets zizou     publication date        2010-10-01
# 12           top gun maverick     film crew member     ashley miller
#
#     Votes_CORRECT  Votes_INCORRECT Corrections_Subject Corrections_Predicate  \
# 0               0                2                 NaN                   NaN
# 1               0                2                 NaN                   NaN
# 2               0                2                 NaN           cast member
# 3               0                2                 NaN          screenwriter
# 4               0                1                 NaN                   NaN
# 5               0                2                 NaN                   NaN
# 6               0                1                 NaN                   NaN
# 7               0                2                 NaN                   NaN
# 8               0                2                 NaN                   NaN
# 9               0                2     horrible bosses                   NaN
# 10              0                1                 NaN                   NaN
# 11              0                2                 NaN                   NaN
# 12              0                2                 NaN          screenwriter
#
#    Corrections_Object
# 0        erika sainte
# 1         rolfe sedan
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5           Q28732985
# 6          2010-01-01
# 7          2011-01-01
# 8           ezgi mola
# 9                 NaN
# 10          698491348
# 11         2011-01-01
# 12                NaN
