# %%
import numpy as np
import pandas as pd
from statsmodels.stats.inter_rater import fleiss_kappa, aggregate_raters
import matplotlib.pyplot as plt

# %%
# read tsv with headers
with open("./exports/crowd_data.tsv", "r") as f:
    crowd_df = pd.read_csv(f, sep="\t")

crowd_df
# Out:
#      HITId HITTypeId                                 Title Reward  \
# 0        1       7QT  Is this triple correct or incorrect?  $0.50
# 1        1       7QT  Is this triple correct or incorrect?  $0.50
# 2        1       7QT  Is this triple correct or incorrect?  $0.50
# 3        1       7QT  Is this triple correct or incorrect?  $0.50
# 4        1       7QT  Is this triple correct or incorrect?  $0.50
# ..     ...       ...                                   ...    ...
# 300     61       9QT  Is this triple correct or incorrect?  $0.50
# 301     61       9QT  Is this triple correct or incorrect?  $0.50
# 302     61       9QT  Is this triple correct or incorrect?  $0.50
# 303     61       9QT  Is this triple correct or incorrect?  $0.50
# 304     61       9QT  Is this triple correct or incorrect?  $0.50
#
#      AssignmentId     WorkerId AssignmentStatus  WorkTimeInSeconds  \
# 0               1  2133ICYWE97        Submitted                 60
# 1               2  2133U7HKDLO        Submitted                 40
# 2               3  928UJANWZ12        Submitted                 50
# 3               4    1726JMZQW        Submitted                 80
# 4               5  2134U7HKDMM        Submitted                  2
# ..            ...          ...              ...                ...
# 300           301    AALKMII97        Submitted                240
# 301           302    HHCKW1111        Submitted                200
# 302           303   GGUI83657S        Submitted                120
# 303           304  WWHL098SA43        Submitted                 10
# 304           305  QZAHIFT8263        Submitted                  2
#
#     LifetimeApprovalRate     Input1ID   Input2ID   Input3ID  AnswerID  \
# 0                    99%    wd:Q11621  wdt:P2142  792910554       1.0
# 1                    40%    wd:Q11621  wdt:P2142  792910554       1.0
# 2                    98%    wd:Q11621  wdt:P2142  792910554       2.0
# 3                    70%    wd:Q11621  wdt:P2142  792910554       1.0
# 4                    70%    wd:Q11621  wdt:P2142  792910554       1.0
# ..                   ...          ...        ...        ...       ...
# 300                  98%  wd:Q1288004  wdt:P1412  wd:Q13330       2.0
# 301                  80%  wd:Q1288004  wdt:P1412  wd:Q13330       1.0
# 302                  85%  wd:Q1288004  wdt:P1412  wd:Q13330       1.0
# 303                  69%  wd:Q1288004  wdt:P1412  wd:Q13330       2.0
# 304                  40%  wd:Q1288004  wdt:P1412  wd:Q13330       2.0
#
#     AnswerLabel FixPosition FixValue
# 0       CORRECT         NaN      NaN
# 1       CORRECT         yes      yes
# 2     INCORRECT         NaN      NaN
# 3       CORRECT         NaN      NaN
# 4       CORRECT         NaN      NaN
# ..          ...         ...      ...
# 300   INCORRECT      Object    Q1860
# 301     CORRECT         NaN      NaN
# 302     CORRECT         NaN      NaN
# 303   INCORRECT         NaN      NaN
# 304   INCORRECT         100      100
#
# [305 rows x 16 columns]

# %%
crowd_df['LifetimeApprovalRate'] = crowd_df['LifetimeApprovalRate'].astype(str).str.rstrip('%').astype(float)
median_rate = crowd_df['LifetimeApprovalRate'].median()
crowd_df = crowd_df[(crowd_df['LifetimeApprovalRate'] >= median_rate)]
print(f"Median lifetime approval rate: {int(median_rate)}%")
crowd_df
# Out:
# Median lifetime approval rate: 80%
#      HITId HITTypeId                                 Title Reward  \
# 0        1       7QT  Is this triple correct or incorrect?  $0.50
# 2        1       7QT  Is this triple correct or incorrect?  $0.50
# 6        2       7QT  Is this triple correct or incorrect?  $0.50
# 7        2       7QT  Is this triple correct or incorrect?  $0.50
# 10       3       7QT  Is this triple correct or incorrect?  $0.50
# ..     ...       ...                                   ...    ...
# 296     60       9QT  Is this triple correct or incorrect?  $0.50
# 297     60       9QT  Is this triple correct or incorrect?  $0.50
# 300     61       9QT  Is this triple correct or incorrect?  $0.50
# 301     61       9QT  Is this triple correct or incorrect?  $0.50
# 302     61       9QT  Is this triple correct or incorrect?  $0.50
#
#      AssignmentId     WorkerId AssignmentStatus  WorkTimeInSeconds  \
# 0               1  2133ICYWE97        Submitted                 60
# 2               3  928UJANWZ12        Submitted                 50
# 6               7  2133ICYWE97        Submitted                120
# 7               8  928UJANWZ12        Submitted                 60
# 10             11  2133ICYWE97        Submitted                140
# ..            ...          ...              ...                ...
# 296           297    HHCKW1111        Submitted                200
# 297           298   GGUI83657S        Submitted                120
# 300           301    AALKMII97        Submitted                240
# 301           302    HHCKW1111        Submitted                200
# 302           303   GGUI83657S        Submitted                120
#
#      LifetimeApprovalRate      Input1ID   Input2ID    Input3ID  AnswerID  \
# 0                    99.0     wd:Q11621  wdt:P2142   792910554       1.0
# 2                    98.0     wd:Q11621  wdt:P2142   792910554       2.0
# 6                    99.0    wd:Q603545  wdt:P2142     4300000       1.0
# 7                    98.0    wd:Q603545  wdt:P2142     4300000       1.0
# 10                   99.0  wd:Q16911843   wdt:P577  2014-01-18       2.0
# ..                    ...           ...        ...         ...       ...
# 296                  80.0  wd:Q21060270    wdt:P27     wd:Q916       1.0
# 297                  85.0  wd:Q21060270    wdt:P27     wd:Q916       1.0
# 300                  98.0   wd:Q1288004  wdt:P1412   wd:Q13330       2.0
# 301                  80.0   wd:Q1288004  wdt:P1412   wd:Q13330       1.0
# 302                  85.0   wd:Q1288004  wdt:P1412   wd:Q13330       1.0
#
#     AnswerLabel FixPosition    FixValue
# 0       CORRECT         NaN         NaN
# 2     INCORRECT         NaN         NaN
# 6       CORRECT         NaN         NaN
# 7       CORRECT         NaN         NaN
# 10    INCORRECT      Object  2014-02-18
# ..          ...         ...         ...
# 296     CORRECT         NaN         NaN
# 297     CORRECT         NaN         NaN
# 300   INCORRECT      Object       Q1860
# 301     CORRECT         NaN         NaN
# 302     CORRECT         NaN         NaN
#
# [162 rows x 16 columns]

# %%
median_rate = crowd_df['WorkTimeInSeconds'].median()
crowd_df = crowd_df[(crowd_df['WorkTimeInSeconds'] >= median_rate)]
print(f"Median work time in seconds: {int(median_rate)}s")
crowd_df
# Out:
# Median work time in seconds: 200s
#      HITId HITTypeId                                 Title Reward  \
# 16       4       7QT  Is this triple correct or incorrect?  $0.50
# 22       5       7QT  Is this triple correct or incorrect?  $0.50
# 36       8       7QT  Is this triple correct or incorrect?  $0.50
# 51      11       7QT  Is this triple correct or incorrect?  $0.50
# 56      12       7QT  Is this triple correct or incorrect?  $0.50
# ..     ...       ...                                   ...    ...
# 291     59       9QT  Is this triple correct or incorrect?  $0.50
# 295     60       9QT  Is this triple correct or incorrect?  $0.50
# 296     60       9QT  Is this triple correct or incorrect?  $0.50
# 300     61       9QT  Is this triple correct or incorrect?  $0.50
# 301     61       9QT  Is this triple correct or incorrect?  $0.50
#
#      AssignmentId     WorkerId AssignmentStatus  WorkTimeInSeconds  \
# 16             17  928UJANWZ12        Submitted                240
# 22             23  928UJANWZ12        Submitted                240
# 36             37  928UJANWZ12        Submitted                240
# 51             52  928UJANWZ12        Submitted                240
# 56             57  928UJANWZ12        Submitted                240
# ..            ...          ...              ...                ...
# 291           292    HHCKW1111        Submitted                200
# 295           296    AALKMII97        Submitted                240
# 296           297    HHCKW1111        Submitted                200
# 300           301    AALKMII97        Submitted                240
# 301           302    HHCKW1111        Submitted                200
#
#      LifetimeApprovalRate       Input1ID                 Input2ID  \
# 16                   98.0     wd:Q132863                wdt:P2142
# 22                   98.0    wd:Q1628022                 wdt:P577
# 36                   98.0     wd:Q217010                wdt:P2142
# 51                   98.0    wd:Q1339195  ddis:indirectSubclassOf
# 56                   98.0  wd:Q104649845  ddis:indirectSubclassOf
# ..                    ...            ...                      ...
# 291                  80.0    wd:Q1893555                 wdt:P272
# 295                  98.0   wd:Q21060270                  wdt:P27
# 296                  80.0   wd:Q21060270                  wdt:P27
# 300                  98.0    wd:Q1288004                wdt:P1412
# 301                  80.0    wd:Q1288004                wdt:P1412
#
#          Input3ID  AnswerID AnswerLabel FixPosition   FixValue
# 16      969023261       2.0   INCORRECT         NaN        NaN
# 22     1951-01-01       1.0     CORRECT         NaN        NaN
# 36      698491347       2.0   INCORRECT      Object  698491348
# 51   wd:Q27096213       2.0   INCORRECT      Object     wd:Q72
# 56      wd:Q43229       1.0     CORRECT         NaN        NaN
# ..            ...       ...         ...         ...        ...
# 291  wd:Q48784114       2.0   INCORRECT      Object   Q7488442
# 295       wd:Q916       2.0   INCORRECT      Object       Q884
# 296       wd:Q916       1.0     CORRECT         NaN        NaN
# 300     wd:Q13330       2.0   INCORRECT      Object      Q1860
# 301     wd:Q13330       1.0     CORRECT         NaN        NaN
#
# [85 rows x 16 columns]

# %%
filtered_df = crowd_df.groupby("HITId").filter(
    lambda group: group[group["AnswerLabel"] == "INCORRECT"].shape[0] >
                  group[group["AnswerLabel"] == "CORRECT"].shape[0]
)
filtered_df
# Out:
#      HITId HITTypeId                                 Title Reward  \
# 16       4       7QT  Is this triple correct or incorrect?  $0.50
# 36       8       7QT  Is this triple correct or incorrect?  $0.50
# 51      11       7QT  Is this triple correct or incorrect?  $0.50
# 66      14       7QT  Is this triple correct or incorrect?  $0.50
# 96      20       7QT  Is this triple correct or incorrect?  $0.50
# 105     22       8QT  Is this triple correct or incorrect?  $0.50
# 110     23       8QT  Is this triple correct or incorrect?  $0.50
# 111     23       8QT  Is this triple correct or incorrect?  $0.50
# 125     26       8QT  Is this triple correct or incorrect?  $0.50
# 126     26       8QT  Is this triple correct or incorrect?  $0.50
# 140     29       8QT  Is this triple correct or incorrect?  $0.50
# 141     29       8QT  Is this triple correct or incorrect?  $0.50
# 165     34       8QT  Is this triple correct or incorrect?  $0.50
# 166     34       8QT  Is this triple correct or incorrect?  $0.50
# 190     39       8QT  Is this triple correct or incorrect?  $0.50
# 200     41       8QT  Is this triple correct or incorrect?  $0.50
# 201     41       8QT  Is this triple correct or incorrect?  $0.50
# 210     43       9QT  Is this triple correct or incorrect?  $0.50
# 211     43       9QT  Is this triple correct or incorrect?  $0.50
# 215     44       9QT  Is this triple correct or incorrect?  $0.50
# 216     44       9QT  Is this triple correct or incorrect?  $0.50
# 225     46       9QT  Is this triple correct or incorrect?  $0.50
# 226     46       9QT  Is this triple correct or incorrect?  $0.50
# 230     47       9QT  Is this triple correct or incorrect?  $0.50
# 231     47       9QT  Is this triple correct or incorrect?  $0.50
# 285     58       9QT  Is this triple correct or incorrect?  $0.50
# 289     58       9QT  Is this triple correct or incorrect?  $0.50
#
#      AssignmentId     WorkerId AssignmentStatus  WorkTimeInSeconds  \
# 16             17  928UJANWZ12        Submitted                240
# 36             37  928UJANWZ12        Submitted                240
# 51             52  928UJANWZ12        Submitted                240
# 66             67  928UJANWZ12        Submitted                240
# 96             97  928UJANWZ12        Submitted                236
# 105           106    AALKMII98        Submitted                337
# 110           111    AALKMII98        Submitted                237
# 111           112    HHCKW1111        Submitted                200
# 125           126    HHCKW1111        Submitted                200
# 126           127    AALKMII98        Submitted                235
# 140           141    AALKMII98        Submitted                240
# 141           142    HHCKW1111        Submitted                200
# 165           166    AALKMII98        Submitted                240
# 166           167    HHCKW1111        Submitted                200
# 190           191    AALKMII98        Submitted                240
# 200           201    AALKMII98        Submitted                241
# 201           202    HHCKW1111        Submitted                200
# 210           211    AALKMII97        Submitted                240
# 211           212    HHCKW1111        Submitted                200
# 215           216    AALKMII97        Submitted                240
# 216           217    HHCKW1111        Submitted                200
# 225           226    AALKMII97        Submitted                240
# 226           227    HHCKW1111        Submitted                200
# 230           231    AALKMII97        Submitted                240
# 231           232    HHCKW1111        Submitted                200
# 285           286    AALKMII97        Submitted                240
# 289           290    HHCKW1111        Submitted                200
#
#      LifetimeApprovalRate      Input1ID                 Input2ID  \
# 16                   98.0    wd:Q132863                wdt:P2142
# 36                   98.0    wd:Q217010                wdt:P2142
# 51                   98.0   wd:Q1339195  ddis:indirectSubclassOf
# 66                   98.0      wd:Q1004  ddis:indirectSubclassOf
# 96                   98.0  wd:Q15239622  ddis:indirectSubclassOf
# 105                  98.0   wd:Q1720855                 wdt:P577
# 110                  98.0    wd:Q598752                 wdt:P577
# 111                  80.0    wd:Q598752                 wdt:P577
# 125                  80.0   wd:Q1410031                 wdt:P577
# 126                  98.0   wd:Q1410031                 wdt:P577
# 140                  98.0    wd:Q639070                 wdt:P161
# 141                  80.0    wd:Q639070                 wdt:P161
# 165                  98.0   wd:Q1039395                 wdt:P161
# 166                  80.0   wd:Q1039395                 wdt:P161
# 190                  98.0    wd:Q814781                wdt:.P344
# 200                  98.0   wd:Q1123629                 wdt:P725
# 201                  80.0   wd:Q1123629                 wdt:P725
# 210                  98.0    wd:Q610633                wdt:P2554
# 211                  80.0    wd:Q610633                wdt:P2554
# 215                  98.0   wd:Q2188914                 wdt:P161
# 216                  80.0   wd:Q2188914                 wdt:P161
# 225                  98.0    wd:Q209538                wdt:P3650
# 226                  80.0    wd:Q209538                wdt:P3650
# 230                  98.0  wd:Q31202708                wdt:P3092
# 231                  80.0  wd:Q31202708                wdt:P3092
# 285                  98.0    wd:Q943992                 wdt:P161
# 289                  80.0    wd:Q943992                 wdt:P161
#
#          Input3ID  AnswerID AnswerLabel FixPosition    FixValue
# 16      969023261       2.0   INCORRECT         NaN         NaN
# 36      698491347       2.0   INCORRECT      Object   698491348
# 51   wd:Q27096213       2.0   INCORRECT      Object      wd:Q72
# 66   wd:Q47461344       2.0   INCORRECT         NaN         NaN
# 96   wd:Q27096213       2.0   INCORRECT         NaN         NaN
# 105    2010-10-01       2.0   INCORRECT      Object  2010-01-01
# 110    2001-01-01       2.0   INCORRECT      Object  2011-01-01
# 111    2001-01-01       2.0   INCORRECT      Object  2011-01-01
# 125    2010-10-01       2.0   INCORRECT      Object  2011-01-01
# 126    2010-10-01       2.0   INCORRECT      Object  2011-01-01
# 140   wd:Q2865083       2.0   INCORRECT      Object    Q5423258
# 141   wd:Q2865083       2.0   INCORRECT      Object    Q5423258
# 165  wd:Q17386547       2.0   INCORRECT     Subject     Q908556
# 166  wd:Q17386547       2.0   INCORRECT     Subject     Q908556
# 190  wd:Q40087803       2.0   INCORRECT     Subject   Q27703272
# 200    wd:Q211040       2.0   INCORRECT   Predicate        P161
# 201    wd:Q211040       2.0   INCORRECT   Predicate        P161
# 210   wd:Q1700810       2.0   INCORRECT   Predicate         P58
# 211   wd:Q1700810       2.0   INCORRECT   Predicate         P58
# 215   wd:Q2416526       2.0   INCORRECT      Object   Q17350908
# 216   wd:Q2416526       2.0   INCORRECT      Object   Q17350908
# 225  wd:Q28732983       2.0   INCORRECT      Object         NaN
# 226  wd:Q28732983       2.0   INCORRECT      Object   Q28732985
# 230   wd:Q4805527       2.0   INCORRECT   Predicate         P58
# 231   wd:Q4805527       2.0   INCORRECT   Predicate         P58
# 285    wd:Q160432       2.0   INCORRECT      Object    Q7360827
# 289    wd:Q160432       2.0   INCORRECT      Object         NaN

# %%
import json
json_files = ["./exports/people_db.json", "./exports/movie_db.json"]
merged_data = {
    k.split("/")[-1]: v
    for file_path in json_files
    for k, v in json.load(open(file_path, 'r')).items()
}

with open("./exports/predicate_db.json", 'r') as f:
    # Reversed index
    merged_data.update({v.split("/")[-1]: k for k, v in json.load(f).items()})

def set_label(identity, required=True):
    identity = str(identity)
    if "/" in identity:
        identity = identity.split("/")[-1]
    elif ":" in identity:
        identity = identity.split(":")[-1]
    return merged_data.get(identity, np.nan if required else identity)

for column in ["Input1ID", "Input2ID", "Input3ID"]:
    filtered_df[column] = filtered_df[column].apply(set_label, required=True)

filtered_df["FixValue"] = filtered_df["FixValue"].apply(set_label, required=False)

filtered_df = filtered_df.dropna(subset=["Input1ID", "Input2ID", "Input3ID"])


filtered_df
# Out:
#      HITId HITTypeId                                 Title Reward  \
# 140     29       8QT  Is this triple correct or incorrect?  $0.50
# 141     29       8QT  Is this triple correct or incorrect?  $0.50
# 165     34       8QT  Is this triple correct or incorrect?  $0.50
# 166     34       8QT  Is this triple correct or incorrect?  $0.50
# 200     41       8QT  Is this triple correct or incorrect?  $0.50
# 201     41       8QT  Is this triple correct or incorrect?  $0.50
# 210     43       9QT  Is this triple correct or incorrect?  $0.50
# 211     43       9QT  Is this triple correct or incorrect?  $0.50
# 215     44       9QT  Is this triple correct or incorrect?  $0.50
# 216     44       9QT  Is this triple correct or incorrect?  $0.50
# 230     47       9QT  Is this triple correct or incorrect?  $0.50
# 231     47       9QT  Is this triple correct or incorrect?  $0.50
# 285     58       9QT  Is this triple correct or incorrect?  $0.50
# 289     58       9QT  Is this triple correct or incorrect?  $0.50
#
#      AssignmentId   WorkerId AssignmentStatus  WorkTimeInSeconds  \
# 140           141  AALKMII98        Submitted                240
# 141           142  HHCKW1111        Submitted                200
# 165           166  AALKMII98        Submitted                240
# 166           167  HHCKW1111        Submitted                200
# 200           201  AALKMII98        Submitted                241
# 201           202  HHCKW1111        Submitted                200
# 210           211  AALKMII97        Submitted                240
# 211           212  HHCKW1111        Submitted                200
# 215           216  AALKMII97        Submitted                240
# 216           217  HHCKW1111        Submitted                200
# 230           231  AALKMII97        Submitted                240
# 231           232  HHCKW1111        Submitted                200
# 285           286  AALKMII97        Submitted                240
# 289           290  HHCKW1111        Submitted                200
#
#      LifetimeApprovalRate                 Input1ID             Input2ID  \
# 140                  98.0        magic carpet ride          cast member
# 141                  80.0        magic carpet ride          cast member
# 165                  98.0  martial arts of shaolin          cast member
# 166                  80.0  martial arts of shaolin          cast member
# 200                  98.0      conan the barbarian          voice actor
# 201                  80.0      conan the barbarian          voice actor
# 210                  98.0                   eskimo  production designer
# 211                  80.0                   eskimo  production designer
# 215                  98.0            a happy event          cast member
# 216                  80.0            a happy event          cast member
# 230                  98.0         top gun maverick     film crew member
# 231                  80.0         top gun maverick     film crew member
# 285                  98.0     a night at the opera          cast member
# 289                  80.0     a night at the opera          cast member
#
#              Input3ID  AnswerID AnswerLabel FixPosition         FixValue
# 140     arthur dupont       2.0   INCORRECT      Object        ezgi mola
# 141     arthur dupont       2.0   INCORRECT      Object        ezgi mola
# 165  peter breitmayer       2.0   INCORRECT     Subject  horrible bosses
# 166  peter breitmayer       2.0   INCORRECT     Subject  horrible bosses
# 200      rose mcgowan       2.0   INCORRECT   Predicate      cast member
# 201      rose mcgowan       2.0   INCORRECT   Predicate      cast member
# 210    john lee mahin       2.0   INCORRECT   Predicate     screenwriter
# 211    john lee mahin       2.0   INCORRECT   Predicate     screenwriter
# 215     theis schmidt       2.0   INCORRECT      Object     erika sainte
# 216     theis schmidt       2.0   INCORRECT      Object     erika sainte
# 230     ashley miller       2.0   INCORRECT   Predicate     screenwriter
# 231     ashley miller       2.0   INCORRECT   Predicate     screenwriter
# 285          jude law       2.0   INCORRECT      Object      rolfe sedan
# 289          jude law       2.0   INCORRECT      Object              nan

# %%
duplicate_answers = crowd_df[crowd_df.duplicated(subset=["WorkerId", "HITId"], keep=False)]
duplicate_summary = duplicate_answers.groupby(["WorkerId", "HITId"]).size().reset_index(name="Duplicate_Count")

if not duplicate_summary.empty:
    print("Workers who answered the same question more than once:")
else:
    print("No workers answered the same question more than once.")
# Out:
# No workers answered the same question more than once.
