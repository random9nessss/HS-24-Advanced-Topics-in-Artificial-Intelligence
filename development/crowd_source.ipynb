# %%
import numpy as np
import pandas as pd
import json

# %%
# read tsv with headers
with open("./exports/crowd_data.tsv", "r") as f:
    crowd_df = pd.read_csv(f, sep="\t", index_col="AssignmentId")
    crowd_df = crowd_df.sort_values(by=["HITId", "WorkerId"])

crowd_df
# Out:
#               HITId HITTypeId                                 Title Reward  \
# AssignmentId
# 4                 1       7QT  Is this triple correct or incorrect?  $0.50
# 1                 1       7QT  Is this triple correct or incorrect?  $0.50
# 2                 1       7QT  Is this triple correct or incorrect?  $0.50
# 5                 1       7QT  Is this triple correct or incorrect?  $0.50
# 3                 1       7QT  Is this triple correct or incorrect?  $0.50
# ...             ...       ...                                   ...    ...
# 301              61       9QT  Is this triple correct or incorrect?  $0.50
# 303              61       9QT  Is this triple correct or incorrect?  $0.50
# 302              61       9QT  Is this triple correct or incorrect?  $0.50
# 305              61       9QT  Is this triple correct or incorrect?  $0.50
# 304              61       9QT  Is this triple correct or incorrect?  $0.50
#
#                  WorkerId AssignmentStatus  WorkTimeInSeconds  \
# AssignmentId
# 4               1726JMZQW        Submitted                 80
# 1             2133ICYWE97        Submitted                 60
# 2             2133U7HKDLO        Submitted                 40
# 5             2134U7HKDMM        Submitted                  2
# 3             928UJANWZ12        Submitted                 50
# ...                   ...              ...                ...
# 301             AALKMII97        Submitted                240
# 303            GGUI83657S        Submitted                120
# 302             HHCKW1111        Submitted                200
# 305           QZAHIFT8263        Submitted                  2
# 304           WWHL098SA43        Submitted                 10
#
#              LifetimeApprovalRate     Input1ID   Input2ID   Input3ID  \
# AssignmentId
# 4                             70%    wd:Q11621  wdt:P2142  792910554
# 1                             99%    wd:Q11621  wdt:P2142  792910554
# 2                             40%    wd:Q11621  wdt:P2142  792910554
# 5                             70%    wd:Q11621  wdt:P2142  792910554
# 3                             98%    wd:Q11621  wdt:P2142  792910554
# ...                           ...          ...        ...        ...
# 301                           98%  wd:Q1288004  wdt:P1412  wd:Q13330
# 303                           85%  wd:Q1288004  wdt:P1412  wd:Q13330
# 302                           80%  wd:Q1288004  wdt:P1412  wd:Q13330
# 305                           40%  wd:Q1288004  wdt:P1412  wd:Q13330
# 304                           69%  wd:Q1288004  wdt:P1412  wd:Q13330
#
#               AnswerID AnswerLabel FixPosition FixValue
# AssignmentId
# 4                  1.0     CORRECT         NaN      NaN
# 1                  1.0     CORRECT         NaN      NaN
# 2                  1.0     CORRECT         yes      yes
# 5                  1.0     CORRECT         NaN      NaN
# 3                  2.0   INCORRECT         NaN      NaN
# ...                ...         ...         ...      ...
# 301                2.0   INCORRECT      Object    Q1860
# 303                1.0     CORRECT         NaN      NaN
# 302                1.0     CORRECT         NaN      NaN
# 305                2.0   INCORRECT         100      100
# 304                2.0   INCORRECT         NaN      NaN
#
# [305 rows x 15 columns]

# %%
crowd_df = crowd_df.drop(columns=["Title", "Reward", "AssignmentStatus"])
crowd_df
# Out:
#               HITId HITTypeId     WorkerId  WorkTimeInSeconds  \
# AssignmentId
# 4                 1       7QT    1726JMZQW                 80
# 1                 1       7QT  2133ICYWE97                 60
# 2                 1       7QT  2133U7HKDLO                 40
# 5                 1       7QT  2134U7HKDMM                  2
# 3                 1       7QT  928UJANWZ12                 50
# ...             ...       ...          ...                ...
# 301              61       9QT    AALKMII97                240
# 303              61       9QT   GGUI83657S                120
# 302              61       9QT    HHCKW1111                200
# 305              61       9QT  QZAHIFT8263                  2
# 304              61       9QT  WWHL098SA43                 10
#
#              LifetimeApprovalRate     Input1ID   Input2ID   Input3ID  \
# AssignmentId
# 4                             70%    wd:Q11621  wdt:P2142  792910554
# 1                             99%    wd:Q11621  wdt:P2142  792910554
# 2                             40%    wd:Q11621  wdt:P2142  792910554
# 5                             70%    wd:Q11621  wdt:P2142  792910554
# 3                             98%    wd:Q11621  wdt:P2142  792910554
# ...                           ...          ...        ...        ...
# 301                           98%  wd:Q1288004  wdt:P1412  wd:Q13330
# 303                           85%  wd:Q1288004  wdt:P1412  wd:Q13330
# 302                           80%  wd:Q1288004  wdt:P1412  wd:Q13330
# 305                           40%  wd:Q1288004  wdt:P1412  wd:Q13330
# 304                           69%  wd:Q1288004  wdt:P1412  wd:Q13330
#
#               AnswerID AnswerLabel FixPosition FixValue
# AssignmentId
# 4                  1.0     CORRECT         NaN      NaN
# 1                  1.0     CORRECT         NaN      NaN
# 2                  1.0     CORRECT         yes      yes
# 5                  1.0     CORRECT         NaN      NaN
# 3                  2.0   INCORRECT         NaN      NaN
# ...                ...         ...         ...      ...
# 301                2.0   INCORRECT      Object    Q1860
# 303                1.0     CORRECT         NaN      NaN
# 302                1.0     CORRECT         NaN      NaN
# 305                2.0   INCORRECT         100      100
# 304                2.0   INCORRECT         NaN      NaN
#
# [305 rows x 12 columns]

# %%
crowd_df['LifetimeApprovalRate'] = crowd_df['LifetimeApprovalRate'].astype(str).str.rstrip('%').astype(float)

median_rate = crowd_df['LifetimeApprovalRate'].median()

correction = 20
crowd_df = crowd_df[(crowd_df['LifetimeApprovalRate'] >= median_rate - correction)]

print(f"Median lifetime approval rate: {int(median_rate)}%")

crowd_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[324], line 1
# ----> 1 crowd_data = crowd_df[crowd_df['LifetimeApprovalRate'] >= 0.5]
#
# File ~\UntrackedFolder\movie-bot\venv\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\UntrackedFolder\movie-bot\venv\Lib\site-packages\pandas\core\arraylike.py:60, in OpsMixin.__ge__(self, other)
#      58 @unpack_zerodim_and_defer("__ge__")
#      59 def __ge__(self, other):
# ---> 60     return self._cmp_method(other, operator.ge)
#
# File ~\UntrackedFolder\movie-bot\venv\Lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6119 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6121 return self._construct_result(res_values, name=res_name)
#
# File ~\UntrackedFolder\movie-bot\venv\Lib\site-packages\pandas\core\ops\array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~\UntrackedFolder\movie-bot\venv\Lib\site-packages\pandas\core\ops\array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# File ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>=' not supported between instances of 'str' and 'float'

# %%
median_rate = crowd_df['WorkTimeInSeconds'].median()

correction = 0
crowd_df = crowd_df[(crowd_df['WorkTimeInSeconds'] >= median_rate - correction)]

print(f"Median work time in seconds: {int(median_rate)}s")
crowd_df
# Out:
#               HITId HITTypeId     WorkerId  WorkTimeInSeconds  \
# AssignmentId
# 4                 1       7QT    1726JMZQW                 80
# 1                 1       7QT  2133ICYWE97                 60
# 5                 1       7QT  2134U7HKDMM                  2
# 3                 1       7QT  928UJANWZ12                 50
# 9                 2       7QT    1726JMZQW                 90
# ...             ...       ...          ...                ...
# 299              60       9QT  WWHL098SA43                 10
# 301              61       9QT    AALKMII97                240
# 303              61       9QT   GGUI83657S                120
# 302              61       9QT    HHCKW1111                200
# 304              61       9QT  WWHL098SA43                 10
#
#               LifetimeApprovalRate      Input1ID   Input2ID   Input3ID  \
# AssignmentId
# 4                             70.0     wd:Q11621  wdt:P2142  792910554
# 1                             99.0     wd:Q11621  wdt:P2142  792910554
# 5                             70.0     wd:Q11621  wdt:P2142  792910554
# 3                             98.0     wd:Q11621  wdt:P2142  792910554
# 9                             70.0    wd:Q603545  wdt:P2142    4300000
# ...                            ...           ...        ...        ...
# 299                           69.0  wd:Q21060270    wdt:P27    wd:Q916
# 301                           98.0   wd:Q1288004  wdt:P1412  wd:Q13330
# 303                           85.0   wd:Q1288004  wdt:P1412  wd:Q13330
# 302                           80.0   wd:Q1288004  wdt:P1412  wd:Q13330
# 304                           69.0   wd:Q1288004  wdt:P1412  wd:Q13330
#
#               AnswerID AnswerLabel FixPosition FixValue
# AssignmentId
# 4                  1.0     CORRECT         NaN      NaN
# 1                  1.0     CORRECT         NaN      NaN
# 5                  1.0     CORRECT         NaN      NaN
# 3                  2.0   INCORRECT         NaN      NaN
# 9                  1.0     CORRECT         NaN      NaN
# ...                ...         ...         ...      ...
# 299                2.0   INCORRECT         NaN      NaN
# 301                2.0   INCORRECT      Object    Q1860
# 303                1.0     CORRECT         NaN      NaN
# 302                1.0     CORRECT         NaN      NaN
# 304                2.0   INCORRECT         NaN      NaN
#
# [244 rows x 12 columns]

# %%
crowd_df = crowd_df.drop(columns=["WorkTimeInSeconds", "LifetimeApprovalRate"])

# %%
filtered_df = crowd_df.groupby("HITId").filter(
    lambda group: group[group["AnswerLabel"] == "INCORRECT"].shape[0] >
                  group[group["AnswerLabel"] == "CORRECT"].shape[0]
)
filtered_df

filtered_df = crowd_df

# %%
json_files = ["./exports/people_db.json", "./exports/movie_db.json"]
merged_data = {
    k.split("/")[-1]: v
    for file_path in json_files
    for k, v in json.load(open(file_path, 'r')).items()
}

with open("./exports/predicate_db.json", 'r') as f:
    # Reversed index
    merged_data.update({v.split("/")[-1]: k for k, v in json.load(f).items()})

def set_label(value, required=True):
    value = str(value)
    if "/" in value:
        value = value.split("/")[-1]
    elif ":" in value:
        value = value.split(":")[-1]
    return merged_data.get(value, np.nan if required else value)

for column in ["Input1ID", "Input2ID"]:
    filtered_df[column] = filtered_df[column].apply(set_label, required=True)

for column in ["Input3ID", "FixValue"]:
    filtered_df[column] = filtered_df[column].apply(set_label, required=False)


filtered_df = filtered_df.dropna(subset=["Input1ID", "Input2ID", "Input3ID"])

filtered_df
# Out:
#               HITId HITTypeId     WorkerId                 Input1ID  \
# AssignmentId
# 4                 1       7QT    1726JMZQW  et the extraterrestrial
# 1                 1       7QT  2133ICYWE97  et the extraterrestrial
# 5                 1       7QT  2134U7HKDMM  et the extraterrestrial
# 3                 1       7QT  928UJANWZ12  et the extraterrestrial
# 9                 2       7QT    1726JMZQW         peaceful warrior
# ...             ...       ...          ...                      ...
# 299              60       9QT  WWHL098SA43            cho geunhyeon
# 301              61       9QT    AALKMII97            nat pendleton
# 303              61       9QT   GGUI83657S            nat pendleton
# 302              61       9QT    HHCKW1111            nat pendleton
# 304              61       9QT  WWHL098SA43            nat pendleton
#
#                                         Input2ID   Input3ID  AnswerID  \
# AssignmentId
# 4                                     box office  792910554       1.0
# 1                                     box office  792910554       1.0
# 5                                     box office  792910554       1.0
# 3                                     box office  792910554       2.0
# 9                                     box office    4300000       1.0
# ...                                          ...        ...       ...
# 299                       country of citizenship       Q916       2.0
# 301           languages spoken written or signed     Q13330       2.0
# 303           languages spoken written or signed     Q13330       1.0
# 302           languages spoken written or signed     Q13330       1.0
# 304           languages spoken written or signed     Q13330       2.0
#
#              AnswerLabel FixPosition FixValue
# AssignmentId
# 4                CORRECT         NaN      nan
# 1                CORRECT         NaN      nan
# 5                CORRECT         NaN      nan
# 3              INCORRECT         NaN      nan
# 9                CORRECT         NaN      nan
# ...                  ...         ...      ...
# 299            INCORRECT         NaN      nan
# 301            INCORRECT      Object    Q1860
# 303              CORRECT         NaN      nan
# 302              CORRECT         NaN      nan
# 304            INCORRECT         NaN      nan
#
# [176 rows x 10 columns]

# %%
duplicate_answers = crowd_df[crowd_df.duplicated(subset=["WorkerId", "HITId"], keep=False)]
duplicate_summary = duplicate_answers.groupby(["WorkerId", "HITId"]).size().reset_index(name="Duplicate_Count")

if not duplicate_summary.empty:
    print("Workers who answered the same question more than once:")
else:
    print("No workers answered the same question more than once.")
# Out:
# No workers answered the same question more than once.

# %%
result = (
    filtered_df.groupby(["Input1ID", "Input2ID", "Input3ID", "HITTypeId"])
    .agg(
        Votes_CORRECT=("AnswerLabel", lambda x: (x == "CORRECT").sum()),
        Votes_INCORRECT=("AnswerLabel", lambda x: (x == "INCORRECT").sum()),
        Corrections_Subject=("FixValue", lambda x: x[filtered_df["FixPosition"] == "Subject"].tolist()),
        Corrections_Predicate=("FixValue", lambda x: x[filtered_df["FixPosition"] == "Predicate"].tolist()),
        Corrections_Object=("FixValue", lambda x: x[filtered_df["FixPosition"] == "Object"].tolist()),
    )
    .reset_index()
)

def ensure_single_value(corrections):
    unique_values = list(set([v for v in corrections if pd.notna(v) and v != "nan"]))
    if len(unique_values) > 1:
        raise ValueError(f"Multiple values found where a single value is expected: {unique_values}")
    return unique_values[0] if unique_values else np.nan

result["Corrections_Subject"] = result["Corrections_Subject"].apply(ensure_single_value)
result["Corrections_Predicate"] = result["Corrections_Predicate"].apply(ensure_single_value)
result["Corrections_Object"] = result["Corrections_Object"].apply(ensure_single_value)


def handle_nan_subject(row):
    """ If subject is wrong, then it is easier to swap the statement and correct the object """
    if not pd.isna(row["Corrections_Subject"]):
        row["Input1ID"], row["Input3ID"] = row["Input3ID"], row["Input1ID"]
        row["Corrections_Object"] = row["Corrections_Subject"]
        row["Corrections_Subject"] = np.nan
    return row

result = result.apply(handle_nan_subject, axis=1)

if not result["Corrections_Subject"].isna().all():
    raise Exception("Not all corrections have been handled")

result = result.drop(columns=["Corrections_Subject"])

result
# Out:
#                                              Input1ID  \
# 0                                       a happy event
# 1                                a night at the opera
# 2                                        william hurt
# 3                                   frederick worlock
# 4                                       cho geunhyeon
# 5                                 conan the barbarian
# 6                                              eskimo
# 7                             et the extraterrestrial
# 8                                        finding nemo
# 9                             free willy 3 the rescue
# 10                                                Q30
# 11                                  god help the girl
# 12                      guardians of the galaxy vol 2
# 13                                       gunter grass
# 14                                in the line of fire
# 15                                         iron man 3
# 16                                             kaboom
# 17                                    kung fu panda 3
# 18                                     les miserables
# 19                                         like crazy
# 20                                     lillian lehman
# 21                                  magic carpet ride
# 22                                   peter breitmayer
# 23                                    masaichi nagata
# 24                                              medea
# 25                                     miranda frigon
# 26                                              mulan
# 27  naruto the movie guardians of the crescent moo...
# 28                                      nat pendleton
# 29                                          nightjohn
# 30                                              Q1860
# 31                                   peaceful warrior
# 32                                          robocop 3
# 33                                   scent of a woman
# 34                              sex death and bowling
# 35                               the browning version
# 36                                      the candidate
# 37                                     the hell of 63
# 38                          the partys just beginning
# 39                          the princess and the frog
# 40                          the twilight saga eclipse
# 41                                    tom meets zizou
# 42                                   top gun maverick
# 43                                   xmen first class
#
#                                 Input2ID                 Input3ID HITTypeId  \
# 0                            cast member            theis schmidt       9QT
# 1                            cast member                 jude law       9QT
# 2                            cast member    behind the candelabra       8QT
# 3                            cast member              bloody mama       8QT
# 4                 country of citizenship                     Q916       9QT
# 5                            voice actor             rose mcgowan       8QT
# 6                    production designer           john lee mahin       9QT
# 7                             box office                792910554       7QT
# 8                             box office                969023261       7QT
# 9                           screenwriter   angel de andres miquel       9QT
# 10                     country of origin                   gandhi       8QT
# 11                      publication date               2014-01-18       7QT
# 12                            box office                863756050       8QT
# 13                       place of burial                    Q1792       9QT
# 14                            box office                176997186       8QT
# 15                       jmk film rating                Q28732983       9QT
# 16                      publication date               2010-10-01       8QT
# 17                            box office                511200000       8QT
# 18                          main subject           claude lelouch       9QT
# 19                      publication date               2001-01-01       8QT
# 20                                 genre                   Q33999       8QT
# 21                           cast member            arthur dupont       8QT
# 22                           cast member  martial arts of shaolin       8QT
# 23                            allegiance                      Q17       9QT
# 24                        distributed by                Q80948336       9QT
# 25                        place of death                    Q2096       9QT
# 26                    production company                Q48784114       9QT
# 27                          art director      tomomichi nishimura       9QT
# 28    languages spoken written or signed                   Q13330       9QT
# 29                      publication date               1996-06-01       7QT
# 30  original language of film or tv show                   normal       9QT
# 31                            box office                  4300000       7QT
# 32                            box office                 10696220       8QT
# 33                      publication date               1982-01-01       8QT
# 34                      publication date               2015-01-05       8QT
# 35                      publication date               1951-01-01       7QT
# 36                      publication date               2008-08-29       7QT
# 37                           cast member         giuseppe rinaldi       9QT
# 38                      publication date               2018-02-24       7QT
# 39                            box office                267000000       7QT
# 40                            box office                698491347       7QT
# 41                      publication date               2010-10-01       8QT
# 42                      film crew member            ashley miller       9QT
# 43                    executive producer         sheryl lee ralph       9QT
#
#     Votes_CORRECT  Votes_INCORRECT    Corrections_Predicate  \
# 0               0                4                      NaN
# 1               1                3                      NaN
# 2               1                3                      NaN
# 3               1                3                      NaN
# 4               2                2                      NaN
# 5               1                3              cast member
# 6               0                4             screenwriter
# 7               3                1                      NaN
# 8               1                3                      NaN
# 9               1                3                      NaN
# 10              2                2                      NaN
# 11              2                2                      NaN
# 12              1                3                      NaN
# 13              2                2           place of birth
# 14              1                3                      NaN
# 15              0                4                      NaN
# 16              2                2                      NaN
# 17              4                0                      NaN
# 18              1                3  director of photography
# 19              0                4                      NaN
# 20              2                2               occupation
# 21              1                3                      NaN
# 22              0                4                      NaN
# 23              2                2   country of citizenship
# 24              3                1                      NaN
# 25              2                2           place of birth
# 26              3                1                      NaN
# 27              3                1                      NaN
# 28              2                2                      NaN
# 29              1                3                      NaN
# 30              2                2                      NaN
# 31              3                1                      NaN
# 32              3                1                      NaN
# 33              3                1                      NaN
# 34              4                0                      NaN
# 35              3                1                      NaN
# 36              1                3                      NaN
# 37              3                1                      NaN
# 38              2                2                      NaN
# 39              2                2                      NaN
# 40              1                3                      NaN
# 41              1                3                      NaN
# 42              0                4             screenwriter
# 43              2                2                      NaN
#
#      Corrections_Object
# 0          erika sainte
# 1           rolfe sedan
# 2    the blue butterfly
# 3               airport
# 4                  Q884
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9          keith walker
# 10  king solomons mines
# 11           2014-02-18
# 12            863756051
# 13                  NaN
# 14            176997168
# 15            Q28732985
# 16           2010-01-01
# 17                  NaN
# 18                  NaN
# 19           2011-01-01
# 20                  NaN
# 21            ezgi mola
# 22      horrible bosses
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26             Q7488442
# 27                  NaN
# 28                Q1860
# 29                  NaN
# 30       prince valiant
# 31                  NaN
# 32             10696210
# 33           1992-01-01
# 34                  NaN
# 35                  NaN
# 36                  NaN
# 37                  NaN
# 38           2019-02-24
# 39                  NaN
# 40            698491348
# 41           2011-01-01
# 42                  NaN
# 43             stan lee

# %%
# Out:
#   Group  Fleiss Kappa
# 0   7QT     -0.102757
# 1   8QT      0.167167
# 2   9QT      0.056937

# %%
result.dropna(subset=["Corrections_Predicate", "Corrections_Object"])
result
# Out:
#                                              Input1ID  \
# 0                                       a happy event
# 1                                a night at the opera
# 2                                        william hurt
# 3                                   frederick worlock
# 4                                       cho geunhyeon
# 5                                 conan the barbarian
# 6                                              eskimo
# 7                             et the extraterrestrial
# 8                                        finding nemo
# 9                             free willy 3 the rescue
# 10                                                Q30
# 11                                  god help the girl
# 12                      guardians of the galaxy vol 2
# 13                                       gunter grass
# 14                                in the line of fire
# 15                                         iron man 3
# 16                                             kaboom
# 17                                    kung fu panda 3
# 18                                     les miserables
# 19                                         like crazy
# 20                                     lillian lehman
# 21                                  magic carpet ride
# 22                                   peter breitmayer
# 23                                    masaichi nagata
# 24                                              medea
# 25                                     miranda frigon
# 26                                              mulan
# 27  naruto the movie guardians of the crescent moo...
# 28                                      nat pendleton
# 29                                          nightjohn
# 30                                              Q1860
# 31                                   peaceful warrior
# 32                                          robocop 3
# 33                                   scent of a woman
# 34                              sex death and bowling
# 35                               the browning version
# 36                                      the candidate
# 37                                     the hell of 63
# 38                          the partys just beginning
# 39                          the princess and the frog
# 40                          the twilight saga eclipse
# 41                                    tom meets zizou
# 42                                   top gun maverick
# 43                                   xmen first class
#
#                                 Input2ID                 Input3ID HITTypeId  \
# 0                            cast member            theis schmidt       9QT
# 1                            cast member                 jude law       9QT
# 2                            cast member    behind the candelabra       8QT
# 3                            cast member              bloody mama       8QT
# 4                 country of citizenship                     Q916       9QT
# 5                            voice actor             rose mcgowan       8QT
# 6                    production designer           john lee mahin       9QT
# 7                             box office                792910554       7QT
# 8                             box office                969023261       7QT
# 9                           screenwriter   angel de andres miquel       9QT
# 10                     country of origin                   gandhi       8QT
# 11                      publication date               2014-01-18       7QT
# 12                            box office                863756050       8QT
# 13                       place of burial                    Q1792       9QT
# 14                            box office                176997186       8QT
# 15                       jmk film rating                Q28732983       9QT
# 16                      publication date               2010-10-01       8QT
# 17                            box office                511200000       8QT
# 18                          main subject           claude lelouch       9QT
# 19                      publication date               2001-01-01       8QT
# 20                                 genre                   Q33999       8QT
# 21                           cast member            arthur dupont       8QT
# 22                           cast member  martial arts of shaolin       8QT
# 23                            allegiance                      Q17       9QT
# 24                        distributed by                Q80948336       9QT
# 25                        place of death                    Q2096       9QT
# 26                    production company                Q48784114       9QT
# 27                          art director      tomomichi nishimura       9QT
# 28    languages spoken written or signed                   Q13330       9QT
# 29                      publication date               1996-06-01       7QT
# 30  original language of film or tv show                   normal       9QT
# 31                            box office                  4300000       7QT
# 32                            box office                 10696220       8QT
# 33                      publication date               1982-01-01       8QT
# 34                      publication date               2015-01-05       8QT
# 35                      publication date               1951-01-01       7QT
# 36                      publication date               2008-08-29       7QT
# 37                           cast member         giuseppe rinaldi       9QT
# 38                      publication date               2018-02-24       7QT
# 39                            box office                267000000       7QT
# 40                            box office                698491347       7QT
# 41                      publication date               2010-10-01       8QT
# 42                      film crew member            ashley miller       9QT
# 43                    executive producer         sheryl lee ralph       9QT
#
#     Votes_CORRECT  Votes_INCORRECT    Corrections_Predicate  \
# 0               0                4                      NaN
# 1               1                3                      NaN
# 2               1                3                      NaN
# 3               1                3                      NaN
# 4               2                2                      NaN
# 5               1                3              cast member
# 6               0                4             screenwriter
# 7               3                1                      NaN
# 8               1                3                      NaN
# 9               1                3                      NaN
# 10              2                2                      NaN
# 11              2                2                      NaN
# 12              1                3                      NaN
# 13              2                2           place of birth
# 14              1                3                      NaN
# 15              0                4                      NaN
# 16              2                2                      NaN
# 17              4                0                      NaN
# 18              1                3  director of photography
# 19              0                4                      NaN
# 20              2                2               occupation
# 21              1                3                      NaN
# 22              0                4                      NaN
# 23              2                2   country of citizenship
# 24              3                1                      NaN
# 25              2                2           place of birth
# 26              3                1                      NaN
# 27              3                1                      NaN
# 28              2                2                      NaN
# 29              1                3                      NaN
# 30              2                2                      NaN
# 31              3                1                      NaN
# 32              3                1                      NaN
# 33              3                1                      NaN
# 34              4                0                      NaN
# 35              3                1                      NaN
# 36              1                3                      NaN
# 37              3                1                      NaN
# 38              2                2                      NaN
# 39              2                2                      NaN
# 40              1                3                      NaN
# 41              1                3                      NaN
# 42              0                4             screenwriter
# 43              2                2                      NaN
#
#      Corrections_Object
# 0          erika sainte
# 1           rolfe sedan
# 2    the blue butterfly
# 3               airport
# 4                  Q884
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9          keith walker
# 10  king solomons mines
# 11           2014-02-18
# 12            863756051
# 13                  NaN
# 14            176997168
# 15            Q28732985
# 16           2010-01-01
# 17                  NaN
# 18                  NaN
# 19           2011-01-01
# 20                  NaN
# 21            ezgi mola
# 22      horrible bosses
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26             Q7488442
# 27                  NaN
# 28                Q1860
# 29                  NaN
# 30       prince valiant
# 31                  NaN
# 32             10696210
# 33           1992-01-01
# 34                  NaN
# 35                  NaN
# 36                  NaN
# 37                  NaN
# 38           2019-02-24
# 39                  NaN
# 40            698491348
# 41           2011-01-01
# 42                  NaN
# 43             stan lee

# %%
import re
import unicodedata


def normalize_string(s):
    """Normalizes strings by removing non-ASCII characters, punctuation, and redundant spaces."""
    normalized = unicodedata.normalize('NFKD', s.lower())
    cleaned = re.sub(r'[^\w\s]', '', normalized.replace("'", "").replace('"', ''))
    return ' '.join(cleaned.split())


def create_correction_index(df):
    """
    Create an index for corrections to be applied to the original data.
    Creates Lookup for subject, list contains (predicate, object, corrected_predicate, corrected_object) tuples

    """
    index = {}
    for _, row in df.iterrows():
        input1_id = row["Input1ID"]
        if input1_id not in index:
            index[input1_id] = []

        if pd.notna(row["Corrections_Predicate"]):
            index[input1_id].append((row["Input2ID"], row["Input3ID"], row["Corrections_Predicate"], row["Input3ID"], row["Votes_CORRECT"], row["Votes_INCORRECT"]))

        if pd.notna(row["Corrections_Object"]):
            index[input1_id].append((row["Input2ID"], row["Input3ID"], row["Input2ID"], row["Corrections_Object"], row["Votes_CORRECT"], row["Votes_INCORRECT"]))

    return index

correction_index = create_correction_index(result)

with open("./exports/crowd_source.json", "w") as f:
    json.dump(correction_index, f, indent=2)
