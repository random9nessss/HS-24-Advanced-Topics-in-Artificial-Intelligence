# %%
from question_types.sparql import SparqlQueries
from tabulate import tabulate
import json
import os

# %%
sparql = SparqlQueries("../dataset/14_graph.nt")
# Out:
# 2024-10-10 18:35:04,551 | INFO | __init__ | Parsing graph
# 2024-10-10 18:35:57,356 | INFO | __init__ | Graph parsed

# %%
def execute_query(query):
    sparql_result = sparql.execute_query(query)
    result_lst = [
        [str(item) for item in (row if isinstance(row, tuple) else [row])]
        for row in sparql_result
    ]
    if not len(result_lst):
        return print("Results were empty")
    headers = [f"Col {idx}" for idx in range(len(result_lst[0]))]
    print(tabulate(result_lst[:min(3, len(result_lst))], headers=headers, tablefmt="grid"))
    return result_lst

# %%
def get_movie_id_by_name(name: str) -> str:
    query = f"""
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX wd: <http://www.wikidata.org/entity/>
        PREFIX wdt: <http://www.wikidata.org/prop/direct/>

        SELECT ?movie WHERE {{
            # ?movie wdt:P31/wdt:P279* wd:Q11424 ;   # Match film or its subclasses
                   rdfs:label ?movieLabel .        # Get the label of the movie
            FILTER(CONTAINS(LCASE(?movieLabel), LCASE("{name}"))) .  # Substring match
            FILTER(LANG(?movieLabel) = "en")       # Only English labels
        }}
        LIMIT 5
    """
    result_list = execute_query(query)
    if result_list:
        return [result[0] for result in result_list][0]
    return result_list


def get_actor_id_by_name(name: str) -> str:
    query = f"""
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX wd: <http://www.wikidata.org/entity/>
        PREFIX wdt: <http://www.wikidata.org/prop/direct/>

        SELECT ?actor ?actorLabel ?imdbID WHERE {{
            # ?actor wdt:P31 wd:Q5 ;                         # Ensure the entity is a human
                   wdt:P106/wdt:P279* wd:Q33999 ;          # Occupation is actor or any subclass
                   rdfs:label ?actorLabel .                # Get actor label

            FILTER(CONTAINS(LCASE(?actorLabel), LCASE("{name}"))) .  # Match name substring in any label
            FILTER(LANG(?actorLabel) = "en")  # English labels only
            
            OPTIONAL {{ ?actor wdt:P345 ?imdbID . }}  # Optional: Include IMDb ID if present
        }}
        LIMIT 5
    """
    result_list = execute_query(query)
    return result_list if result_list else None

def get_film_professional_id_by_name(name: str) -> str:
    query = f"""
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX wd: <http://www.wikidata.org/entity/>
        PREFIX wdt: <http://www.wikidata.org/prop/direct/>

        SELECT ?professional ?label ?roleLabel WHERE {{
            # ?professional rdfs:label ?label ;        # Get any label
                          wdt:P31 wd:Q5 ;            # Instance of human
                          wdt:P106 ?role .           # Occupation property

            # Include relevant film industry professions and subclasses
            # ?role rdfs:label ?roleLabel .            # Get role label (for debugging)
            FILTER(LANG(?roleLabel) = "en") .        # English labels for roles
            FILTER(CONTAINS(LCASE(?label), LCASE("{name}"))) .  # Match name substring in any label
            FILTER(LANG(?label) = "en")              # English labels only
        }}
        LIMIT 10
    """
    result_list = execute_query(query)
    if result_list and result_list[0]:
        return result_list[0][0]
    return result_list

def get_imdb_id_by_name(name: str) -> str:
    query = f"""
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX wd: <http://www.wikidata.org/entity/>
        PREFIX wdt: <http://www.wikidata.org/prop/direct/>

        SELECT ?imdbId ?entity  WHERE {{
            # ?entity rdfs:label ?label ;
                    wdt:P345 ?imdbId .                # IMDb ID property
            FILTER(CONTAINS(LCASE(?label), LCASE("{name}"))) .  # Match name substring
            FILTER(LANG(?label) = "en")               # English labels only
        }}
        LIMIT 1
    """
    result_list = execute_query(query)
    if result_list and result_list[0]:
        return result_list[0][0]
    return result_list

# %%
def get_all_predicates_by_id(entity_id: str) -> list:
    query = f"""
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX wd: <http://www.wikidata.org/entity/>
        PREFIX wdt: <http://www.wikidata.org/prop/direct/>
        
        SELECT ?predicate ?predicateLabel ?object ?objectLabel WHERE {{
            wd:{entity_id} ?predicate ?object .  # Retrieve all properties and values for the given entity
            OPTIONAL {{ ?predicate rdfs:label ?predicateLabel . FILTER(LANG(?predicateLabel) = "en") }}  # Get predicate label
            OPTIONAL {{ ?object rdfs:label ?objectLabel . FILTER(LANG(?objectLabel) = "en") }}           # Get object label
        }}
        ORDER BY ?predicate
    """
    return execute_query(query)

# %%
def get_all_of_type_film():
    query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX wd: <http://www.wikidata.org/entity/>
        PREFIX wdt: <http://www.wikidata.org/prop/direct/>
        PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
        PREFIX ddis: <http://ddis.ch/atai/>
        
        SELECT ?movieLabel ?movie ?imdbID WHERE {
            # ?movie wdt:P31/wdt:P279* wd:Q11424 .  # instance of film or any subclass of film
            # ?movie rdfs:label ?movieLabel .  # only films with a label
            OPTIONAL { ?movie wdt:P345 ?imdbID . }  # IMDb ID
            FILTER(LANG(?movieLabel) = "en") .
        }
        ORDER BY ?movieLabel
    """
    return execute_query(query)


def get_all_of_type_actor():
    query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX wd: <http://www.wikidata.org/entity/>
        PREFIX wdt: <http://www.wikidata.org/prop/direct/>
        PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
        PREFIX ddis: <http://ddis.ch/atai/>

        SELECT ?actorLabel ?actor ?imdbID WHERE {
            # ?actor wdt:P31 wd:Q5 ;  # instance of human
                   wdt:P106/wdt:P279* wd:Q33999 ;  # occupation is an actor or any subclass of actor
                   rdfs:label ?actorLabel .
            FILTER(LANG(?actorLabel) = "en")
            OPTIONAL { ?actor wdt:P345 ?imdbID . }  # IMDb ID
        }
        ORDER BY ?actorLabel
    """
    return execute_query(query)

def get_all_of_type_film_professionals():
    query = """
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX wd: <http://www.wikidata.org/entity/>
        PREFIX wdt: <http://www.wikidata.org/prop/direct/>
        PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
        PREFIX ddis: <http://ddis.ch/atai/>

        SELECT ?personLabel ?person ?imdbID ?roleLabel WHERE {
            # ?person wdt:P31 wd:Q5 ;  # instance of human
                   wdt:P106 ?role ;  # occupation
                   rdfs:label ?personLabel .
            FILTER(LANG(?personLabel) = "en")
            
            # Include relevant film industry professions
            VALUES ?role { 
                wd:Q2526255  # film director
                wd:Q947873   # film producer
                wd:Q28389    # screenwriter
                wd:Q488111   # cinematographer
                wd:Q3455803  # film editor
                wd:Q36479    # composer
                wd:Q3282637  # voice actor
            }
            
            OPTIONAL { ?role rdfs:label ?roleLabel FILTER(LANG(?roleLabel) = "en") . }  # Get occupation label
            OPTIONAL { ?person wdt:P345 ?imdbID . }  # IMDb ID
        }
        ORDER BY ?personLabel
    """
    return execute_query(query)

# %%
def ensure_directory_exists(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)

def export_actor_json():
    try:
        ensure_directory_exists('exports')
        actor_lst = get_all_of_type_actor()
        db = {row[0]: (row[1], row[2]) for row in actor_lst}  
        with open('exports/actors_db.json', 'w') as file:
            json.dump(db, file)
        print(f"Actor data exported successfully. Stored {len(db)} actors.")
    except Exception as e:
        print(f"An error occurred: {e}")

def export_professionals_json():
    try:
        ensure_directory_exists('exports')
        actor_lst = get_all_of_type_film_professionals()
        db = {row[0]: (row[1], row[2]) for row in actor_lst}  
        with open('exports/professionals_db.json', 'w') as file:
            json.dump(db, file)
        print(f"Actor data exported successfully. Stored {len(db)} actors.")
    except Exception as e:
        print(f"An error occurred: {e}")

def export_film_json():
    try:
        ensure_directory_exists('exports')
        film_lst = get_all_of_type_film()
        db = {row[0]: (row[1], row[2]) for row in film_lst}
        with open('exports/film_db.json', 'w') as file:
            json.dump(db, file)
        print(f"Film data exported successfully. Stored {len(db)} films.")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
def search_anything_by_name(name: str):
    query = f"""
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX wd: <http://www.wikidata.org/entity/>
        PREFIX wdt: <http://www.wikidata.org/prop/direct/>
        PREFIX schema: <http://schema.org/>

        SELECT ?entity ?label ?description WHERE {{
            # ?entity rdfs:label ?label .        # Get any entity with a label
            OPTIONAL {{ ?entity schema:description ?description FILTER(LANG(?description) = "en") }}  # Get descriptions if available
            FILTER(CONTAINS(LCASE(?label), LCASE("{name}"))) .  # Match name substring, case-insensitive
            FILTER(LANG(?label) = "en")  # English labels only
        }}
        LIMIT 10
    """
    return execute_query(query)

# %%
export_film_json()
# Out:
# +-----------------------+-----------------------------------------+-----------+
# | Col 0                 | Col 1                                   | Col 2     |
# +=======================+=========================================+===========+
# | "Crocodile" Dundee    | http://www.wikidata.org/entity/Q615254  | tt0090555 |
# +-----------------------+-----------------------------------------+-----------+
# | "Crocodile" Dundee II | http://www.wikidata.org/entity/Q1140745 | tt0092493 |
# +-----------------------+-----------------------------------------+-----------+
# | #1 Cheerleader Camp   | http://www.wikidata.org/entity/Q2299302 | tt1637976 |
# +-----------------------+-----------------------------------------+-----------+
# Film data exported successfully. Stored 25523 films.

# %%
export_actor_json()
# Out:
# +---------------------+-----------------------------------------+-----------+
# | Col 0               | Col 1                                   | Col 2     |
# +=====================+=========================================+===========+
# | "Weird Al" Yankovic | http://www.wikidata.org/entity/Q8349    | nm0946148 |
# +---------------------+-----------------------------------------+-----------+
# | "Weird Al" Yankovic | http://www.wikidata.org/entity/Q8349    | nm0946148 |
# +---------------------+-----------------------------------------+-----------+
# | 40                  | http://www.wikidata.org/entity/Q3599072 | nm0790520 |
# +---------------------+-----------------------------------------+-----------+
# Actor data exported successfully. Stored 56177 actors.

# %%
export_professionals_json()
# Out:
# Results were empty
# An error occurred: 'NoneType' object is not iterable

# %%
search_anything_by_name("Quentin Tarantino")
# Out:
# +--------------------------------------+-------------------+-----------------------------------------------------------+
# | Col 0                                | Col 1             | Col 2                                                     |
# +======================================+===================+===========================================================+
# | http://www.wikidata.org/entity/Q3772 | Quentin Tarantino | American film director, screenwriter, producer, and actor |
# +--------------------------------------+-------------------+-----------------------------------------------------------+
# [['http://www.wikidata.org/entity/Q3772',
#   'Quentin Tarantino',
#   'American film director, screenwriter, producer, and actor']]

# %%
get_imdb_id_by_name("Avatar")
# Out:
# +-----------+---------------------------------------+
# | Col 0     | Col 1                                 |
# +===========+=======================================+
# | tt0499549 | http://www.wikidata.org/entity/Q24871 |
# +-----------+---------------------------------------+
# 'tt0499549'

# %%
get_movie_id_by_name("Avatar")
# Out:
# +------------------------------------------+
# | Col 0                                    |
# +==========================================+
# | http://www.wikidata.org/entity/Q24871    |
# +------------------------------------------+
# | http://www.wikidata.org/entity/Q29580929 |
# +------------------------------------------+
# | http://www.wikidata.org/entity/Q3604746  |
# +------------------------------------------+
# 'http://www.wikidata.org/entity/Q24871'

# %%
get_film_professional_id_by_name("Quentin Tarantino")
# Out:
# +--------------------------------------+-------------------+---------+
# | Col 0                                | Col 1             | Col 2   |
# +======================================+===================+=========+
# | http://www.wikidata.org/entity/Q3772 | Quentin Tarantino | actor   |
# +--------------------------------------+-------------------+---------+
# | http://www.wikidata.org/entity/Q3772 | Quentin Tarantino | writer  |
# +--------------------------------------+-------------------+---------+
# 'http://www.wikidata.org/entity/Q3772'

# %%
get_film_professional_id_by_name("Hans Zimmer")
# Out:
# +---------------------------------------+-------------+----------+
# | Col 0                                 | Col 1       | Col 2    |
# +=======================================+=============+==========+
# | http://www.wikidata.org/entity/Q76364 | Hans Zimmer | musician |
# +---------------------------------------+-------------+----------+
# 'http://www.wikidata.org/entity/Q76364'

# %%
get_actor_id_by_name("Angelina Jolie")
get_all_predicates_by_id("Q13909")
# Out:
# +---------------------------------------+----------------+-----------+
# | Col 0                                 | Col 1          | Col 2     |
# +=======================================+================+===========+
# | http://www.wikidata.org/entity/Q13909 | Angelina Jolie | nm0001401 |
# +---------------------------------------+----------------+-----------+
# +--------------------------------------------+------------------+--------------------------------------------------------+------------------+
# | Col 0                                      | Col 1            | Col 2                                                  | Col 3            |
# +============================================+==================+========================================================+==================+
# | http://schema.org/description              | node description | American actress, filmmaker, screenwriter and producer | None             |
# +--------------------------------------------+------------------+--------------------------------------------------------+------------------+
# | http://www.w3.org/2000/01/rdf-schema#label | node label       | Angelina Jolie                                         | None             |
# +--------------------------------------------+------------------+--------------------------------------------------------+------------------+
# | http://www.wikidata.org/prop/direct/P103   | native language  | http://www.wikidata.org/entity/Q7976                   | American English |
# +--------------------------------------------+------------------+--------------------------------------------------------+------------------+
# [['http://schema.org/description',
#   'node description',
#   'American actress, filmmaker, screenwriter and producer',
#   'None'],
#  ['http://www.w3.org/2000/01/rdf-schema#label',
#   'node label',
#   'Angelina Jolie',
#   'None'],
#  ['http://www.wikidata.org/prop/direct/P103',
#   'native language',
#   'http://www.wikidata.org/entity/Q7976',
#   'American English'],
#  ['http://www.wikidata.org/prop/direct/P1038',
#   'relative',
#   'http://www.wikidata.org/entity/Q962604',
#   'Chip Taylor'],
#  ['http://www.wikidata.org/prop/direct/P106',
#   'occupation',
#   'http://www.wikidata.org/entity/Q1053574',
#   'executive producer'],
#  ['http://www.wikidata.org/prop/direct/P106',
#   'occupation',
#   'http://www.wikidata.org/entity/Q1414443',
#   'filmmaker'],
#  ['http://www.wikidata.org/prop/direct/P106',
#   'occupation',
#   'http://www.wikidata.org/entity/Q33999',
#   'actor'],
#  ['http://www.wikidata.org/prop/direct/P106',
#   'occupation',
#   'http://www.wikidata.org/entity/Q36180',
#   'writer'],
#  ['http://www.wikidata.org/prop/direct/P106',
#   'occupation',
#   'http://www.wikidata.org/entity/Q4610556',
#   'model'],
#  ['http://www.wikidata.org/prop/direct/P1343',
#   'described by source',
#   'http://www.wikidata.org/entity/Q67311526',
#   'Obalky knih.cz'],
#  ['http://www.wikidata.org/prop/direct/P140',
#   'religion',
#   'http://www.wikidata.org/entity/Q1841',
#   'Catholicism'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q1011564',
#   'Golden Globe Award for Best Actress – Motion Picture Musical or Comedy'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q103618',
#   'Academy Award for Best Actress'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q106301',
#   'Academy Award for Best Supporting Actress'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q463085',
#   'Golden Globe Award for Best Actress – Motion Picture Drama'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q602866',
#   'Golden Raspberry Award for Worst Actress'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q654620',
#   'Screen Actors Guild Award for Outstanding Performance by a Male Actor in a Leading Role'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q687123',
#   'BAFTA Award for Best Actress in a Leading Role'],
#  ['http://www.wikidata.org/prop/direct/P1412',
#   'languages spoken, written or signed',
#   'http://www.wikidata.org/entity/Q1860',
#   'English'],
#  ['http://www.wikidata.org/prop/direct/P1412',
#   'languages spoken, written or signed',
#   'http://www.wikidata.org/entity/Q7976',
#   'American English'],
#  ['http://www.wikidata.org/prop/direct/P1412',
#   'languages spoken, written or signed',
#   'http://www.wikidata.org/entity/Q9205',
#   'Khmer'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q106301',
#   'Academy Award for Best Supporting Actress'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q115737',
#   'Saturn Award for Best Action or Adventure Film'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q1320315',
#   'Screen Actors Guild Award for Outstanding Performance by a Female Actor in a Supporting Role'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q1413741',
#   'Saturn Award for Best Actress'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q18681625',
#   'Hollywood Film Awards'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q2462064',
#   'Screen Actors Guild Award for Outstanding Performance by a Female Actor in a Miniseries or Television Movie'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q501058',
#   "People's Choice Awards"],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q822907',
#   'Golden Globe Award for Best Supporting Actress – Motion Picture'],
#  ['http://www.wikidata.org/prop/direct/P18',
#   'image',
#   'https://commons.wikimedia.org/wiki/File:Angelina_Jolie_2_June_2014_(cropped).jpg',
#   'None'],
#  ['http://www.wikidata.org/prop/direct/P19',
#   'place of birth',
#   'http://www.wikidata.org/entity/Q65',
#   'Los Angeles'],
#  ['http://www.wikidata.org/prop/direct/P22',
#   'father',
#   'http://www.wikidata.org/entity/Q167520',
#   'Jon Voight'],
#  ['http://www.wikidata.org/prop/direct/P25',
#   'mother',
#   'http://www.wikidata.org/entity/Q235845',
#   'Marcheline Bertrand'],
#  ['http://www.wikidata.org/prop/direct/P26',
#   'spouse',
#   'http://www.wikidata.org/entity/Q202735',
#   'Billy Bob Thornton'],
#  ['http://www.wikidata.org/prop/direct/P26',
#   'spouse',
#   'http://www.wikidata.org/entity/Q35332',
#   'Brad Pitt'],
#  ['http://www.wikidata.org/prop/direct/P26',
#   'spouse',
#   'http://www.wikidata.org/entity/Q7516',
#   'Jonny Lee Miller'],
#  ['http://www.wikidata.org/prop/direct/P27',
#   'country of citizenship',
#   'http://www.wikidata.org/entity/Q30',
#   'United States of America'],
#  ['http://www.wikidata.org/prop/direct/P27',
#   'country of citizenship',
#   'http://www.wikidata.org/entity/Q424',
#   'Cambodia'],
#  ['http://www.wikidata.org/prop/direct/P31',
#   'instance of',
#   'http://www.wikidata.org/entity/Q5',
#   'human'],
#  ['http://www.wikidata.org/prop/direct/P3373',
#   'sibling',
#   'http://www.wikidata.org/entity/Q560170',
#   'James Haven'],
#  ['http://www.wikidata.org/prop/direct/P345', 'IMDb ID', 'nm0001401', 'None'],
#  ['http://www.wikidata.org/prop/direct/P451',
#   'unmarried partner',
#   'http://www.wikidata.org/entity/Q35332',
#   'Brad Pitt'],
#  ['http://www.wikidata.org/prop/direct/P451',
#   'unmarried partner',
#   'http://www.wikidata.org/entity/Q432710',
#   'Jenny Shimizu'],
#  ['http://www.wikidata.org/prop/direct/P551',
#   'residence',
#   'http://www.wikidata.org/entity/Q65',
#   'Los Angeles'],
#  ['http://www.wikidata.org/prop/direct/P66',
#   'ancestral home',
#   'http://www.wikidata.org/entity/Q183',
#   'Germany'],
#  ['http://www.wikidata.org/prop/direct/P793',
#   'significant event',
#   'http://www.wikidata.org/entity/Q180472',
#   'adoption'],
#  ['http://www.wikidata.org/prop/direct/P800',
#   'notable work',
#   'http://www.wikidata.org/entity/Q275553',
#   'Changeling'],
#  ['http://www.wikidata.org/prop/direct/P800',
#   'notable work',
#   'http://www.wikidata.org/entity/Q429557',
#   'Gia'],
#  ['http://www.wikidata.org/prop/direct/P800',
#   'notable work',
#   'http://www.wikidata.org/entity/Q463101',
#   'Girl, Interrupted']]

# %%
get_movie_id_by_name("The Naked Gun")
# Out:
# +----------------------------------------+
# | Col 0                                  |
# +========================================+
# | http://www.wikidata.org/entity/Q502979 |
# +----------------------------------------+
# | http://www.wikidata.org/entity/Q832047 |
# +----------------------------------------+
# 'http://www.wikidata.org/entity/Q502979'

# %%
get_imdb_id_by_name("The Naked Gun")
# Out:
# +-----------+----------------------------------------+
# | Col 0     | Col 1                                  |
# +===========+========================================+
# | tt0102510 | http://www.wikidata.org/entity/Q502979 |
# +-----------+----------------------------------------+
# 'tt0102510'

# %%
# Get movie ID
print(get_movie_id_by_name("Inception"))

# Get actor IDs for Brad Pitt
print(get_actor_id_by_name("Brad Pitt"))

# Get film professional ID for Quentin Tarantino
print(get_film_professional_id_by_name("Quentin Tarantino"))

# Get IMDb ID for a name
print(get_imdb_id_by_name("Brad Pitt"))
# Out:
# +---------------------------------------+
# | Col 0                                 |
# +=======================================+
# | http://www.wikidata.org/entity/Q25188 |
# +---------------------------------------+
# http://www.wikidata.org/entity/Q25188
# +---------------------------------------+-----------+-----------+
# | Col 0                                 | Col 1     | Col 2     |
# +=======================================+===========+===========+
# | http://www.wikidata.org/entity/Q35332 | Brad Pitt | nm0000093 |
# +---------------------------------------+-----------+-----------+
# [['http://www.wikidata.org/entity/Q35332', 'Brad Pitt', 'nm0000093']]
# +--------------------------------------+-------------------+---------+
# | Col 0                                | Col 1             | Col 2   |
# +======================================+===================+=========+
# | http://www.wikidata.org/entity/Q3772 | Quentin Tarantino | actor   |
# +--------------------------------------+-------------------+---------+
# | http://www.wikidata.org/entity/Q3772 | Quentin Tarantino | writer  |
# +--------------------------------------+-------------------+---------+
# http://www.wikidata.org/entity/Q3772
# +-----------+---------------------------------------+
# | Col 0     | Col 1                                 |
# +===========+=======================================+
# | nm0000093 | http://www.wikidata.org/entity/Q35332 |
# +-----------+---------------------------------------+
# nm0000093

# %%
get_all_predicates_by_id("Q3772") # Quentin Tarantino
# Out:
# +--------------------------------------------+------------------+-----------------------------------------------------------+---------+
# | Col 0                                      | Col 1            | Col 2                                                     | Col 3   |
# +============================================+==================+===========================================================+=========+
# | http://schema.org/description              | node description | American film director, screenwriter, producer, and actor | None    |
# +--------------------------------------------+------------------+-----------------------------------------------------------+---------+
# | http://www.w3.org/2000/01/rdf-schema#label | node label       | Quentin Tarantino                                         | None    |
# +--------------------------------------------+------------------+-----------------------------------------------------------+---------+
# | http://www.wikidata.org/prop/direct/P106   | occupation       | http://www.wikidata.org/entity/Q33999                     | actor   |
# +--------------------------------------------+------------------+-----------------------------------------------------------+---------+
# [['http://schema.org/description',
#   'node description',
#   'American film director, screenwriter, producer, and actor',
#   'None'],
#  ['http://www.w3.org/2000/01/rdf-schema#label',
#   'node label',
#   'Quentin Tarantino',
#   'None'],
#  ['http://www.wikidata.org/prop/direct/P106',
#   'occupation',
#   'http://www.wikidata.org/entity/Q33999',
#   'actor'],
#  ['http://www.wikidata.org/prop/direct/P106',
#   'occupation',
#   'http://www.wikidata.org/entity/Q36180',
#   'writer'],
#  ['http://www.wikidata.org/prop/direct/P1343',
#   'described by source',
#   'http://www.wikidata.org/entity/Q67311526',
#   'Obalky knih.cz'],
#  ['http://www.wikidata.org/prop/direct/P136',
#   'genre',
#   'http://www.wikidata.org/entity/Q188473',
#   'action film'],
#  ['http://www.wikidata.org/prop/direct/P136',
#   'genre',
#   'http://www.wikidata.org/entity/Q459290',
#   'independent film'],
#  ['http://www.wikidata.org/prop/direct/P140',
#   'religion',
#   'http://www.wikidata.org/entity/Q5043',
#   'Christianity'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q103360',
#   'Academy Award for Best Director'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q1377772',
#   'European Film Award for Best Non-European Film'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q41417',
#   'Academy Award for Best Writing, Original Screenplay'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q849124',
#   'Golden Globe Award for Best Screenplay'],
#  ['http://www.wikidata.org/prop/direct/P1412',
#   'languages spoken, written or signed',
#   'http://www.wikidata.org/entity/Q1860',
#   'English'],
#  ['http://www.wikidata.org/prop/direct/P1412',
#   'languages spoken, written or signed',
#   'http://www.wikidata.org/entity/Q188',
#   'German'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q1789102',
#   'National Board of Review Award for Best Film'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q179808',
#   "Palme d'Or"],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q41375',
#   'BAFTA Award for Best Original Screenplay'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q41417',
#   'Academy Award for Best Writing, Original Screenplay'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q849124',
#   'Golden Globe Award for Best Screenplay'],
#  ['http://www.wikidata.org/prop/direct/P18',
#   'image',
#   'https://commons.wikimedia.org/wiki/File:Quentin_Tarantino.jpg',
#   'None'],
#  ['http://www.wikidata.org/prop/direct/P18',
#   'image',
#   'https://commons.wikimedia.org/wiki/File:Quentin_Tarantino_by_Gage_Skidmore.jpg',
#   'None'],
#  ['http://www.wikidata.org/prop/direct/P22',
#   'father',
#   'http://www.wikidata.org/entity/Q4818309',
#   'Tony Tarantino'],
#  ['http://www.wikidata.org/prop/direct/P27',
#   'country of citizenship',
#   'http://www.wikidata.org/entity/Q30',
#   'United States of America'],
#  ['http://www.wikidata.org/prop/direct/P31',
#   'instance of',
#   'http://www.wikidata.org/entity/Q5',
#   'human'],
#  ['http://www.wikidata.org/prop/direct/P345', 'IMDb ID', 'nm0000233', 'None'],
#  ['http://www.wikidata.org/prop/direct/P451',
#   'unmarried partner',
#   'http://www.wikidata.org/entity/Q212026',
#   'Mira Sorvino'],
#  ['http://www.wikidata.org/prop/direct/P451',
#   'unmarried partner',
#   'http://www.wikidata.org/entity/Q5274115',
#   'Didem Erol'],
#  ['http://www.wikidata.org/prop/direct/P6379',
#   'has works in the collection',
#   'http://www.wikidata.org/entity/Q188740',
#   'Museum of Modern Art'],
#  ['http://www.wikidata.org/prop/direct/P737',
#   'influenced by',
#   'http://www.wikidata.org/entity/Q51581',
#   'Howard Hawks']]

# %%
get_all_predicates_by_id("Q35332") # Brad Pitt
# Out:
# +--------------------------------------------+------------------+--------------------------------------+------------------+
# | Col 0                                      | Col 1            | Col 2                                | Col 3            |
# +============================================+==================+======================================+==================+
# | http://schema.org/description              | node description | American actor and filmmaker         | None             |
# +--------------------------------------------+------------------+--------------------------------------+------------------+
# | http://www.w3.org/2000/01/rdf-schema#label | node label       | Brad Pitt                            | None             |
# +--------------------------------------------+------------------+--------------------------------------+------------------+
# | http://www.wikidata.org/prop/direct/P103   | native language  | http://www.wikidata.org/entity/Q7976 | American English |
# +--------------------------------------------+------------------+--------------------------------------+------------------+
# [['http://schema.org/description',
#   'node description',
#   'American actor and filmmaker',
#   'None'],
#  ['http://www.w3.org/2000/01/rdf-schema#label',
#   'node label',
#   'Brad Pitt',
#   'None'],
#  ['http://www.wikidata.org/prop/direct/P103',
#   'native language',
#   'http://www.wikidata.org/entity/Q7976',
#   'American English'],
#  ['http://www.wikidata.org/prop/direct/P106',
#   'occupation',
#   'http://www.wikidata.org/entity/Q1053574',
#   'executive producer'],
#  ['http://www.wikidata.org/prop/direct/P106',
#   'occupation',
#   'http://www.wikidata.org/entity/Q33999',
#   'actor'],
#  ['http://www.wikidata.org/prop/direct/P106',
#   'occupation',
#   'http://www.wikidata.org/entity/Q4610556',
#   'model'],
#  ['http://www.wikidata.org/prop/direct/P1066',
#   'student of',
#   'http://www.wikidata.org/entity/Q7373081',
#   'Roy London'],
#  ['http://www.wikidata.org/prop/direct/P1343',
#   'described by source',
#   'http://www.wikidata.org/entity/Q67311526',
#   'Obalky knih.cz'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q102427',
#   'Academy Award for Best Picture'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q103916',
#   'Academy Award for Best Actor'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q106291',
#   'Academy Award for Best Supporting Actor'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q628637',
#   "European Film Award – People's Choice Award for Best European Film"],
#  ['http://www.wikidata.org/prop/direct/P1412',
#   'languages spoken, written or signed',
#   'http://www.wikidata.org/entity/Q1860',
#   'English'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q1011547',
#   'Golden Globe Award'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q102427',
#   'Academy Award for Best Picture'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q106291',
#   'Academy Award for Best Supporting Actor'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q1258647',
#   'Saturn Award for Best Supporting Actor'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q1790281',
#   'New York Film Critics Circle Award for Best Actor'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q1967731',
#   'National Society of Film Critics Award for Best Actor'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q3077281',
#   'Rembrandt Award'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q518675',
#   'Screen Actors Guild Award for Outstanding Performance by a Cast in a Motion Picture'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q723830',
#   'Golden Globe Award for Best Supporting Actor – Motion Picture'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q732997',
#   'British Academy Film Awards'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q894591',
#   'Boston Society of Film Critics Award for Best Actor'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q922396',
#   'Broadcast Film Critics Association Award for Best Cast'],
#  ['http://www.wikidata.org/prop/direct/P18',
#   'image',
#   'https://commons.wikimedia.org/wiki/File:Brad_Pitt_2019_by_Glenn_Francis.jpg',
#   'None'],
#  ['http://www.wikidata.org/prop/direct/P1830',
#   'owner of',
#   'http://www.wikidata.org/entity/Q28252',
#   'Plan B Entertainment'],
#  ['http://www.wikidata.org/prop/direct/P26',
#   'spouse',
#   'http://www.wikidata.org/entity/Q13909',
#   'Angelina Jolie'],
#  ['http://www.wikidata.org/prop/direct/P26',
#   'spouse',
#   'http://www.wikidata.org/entity/Q32522',
#   'Jennifer Aniston'],
#  ['http://www.wikidata.org/prop/direct/P27',
#   'country of citizenship',
#   'http://www.wikidata.org/entity/Q30',
#   'United States of America'],
#  ['http://www.wikidata.org/prop/direct/P31',
#   'instance of',
#   'http://www.wikidata.org/entity/Q5',
#   'human'],
#  ['http://www.wikidata.org/prop/direct/P345', 'IMDb ID', 'nm0000093', 'None'],
#  ['http://www.wikidata.org/prop/direct/P451',
#   'unmarried partner',
#   'http://www.wikidata.org/entity/Q13909',
#   'Angelina Jolie'],
#  ['http://www.wikidata.org/prop/direct/P451',
#   'unmarried partner',
#   'http://www.wikidata.org/entity/Q32522',
#   'Jennifer Aniston'],
#  ['http://www.wikidata.org/prop/direct/P451',
#   'unmarried partner',
#   'http://www.wikidata.org/entity/Q34460',
#   'Gwyneth Paltrow'],
#  ['http://www.wikidata.org/prop/direct/P551',
#   'residence',
#   'http://www.wikidata.org/entity/Q65',
#   'Los Angeles']]

# %%
get_all_predicates_by_id("Q25188") # Inception
# Out:
# +-------------------------+---------+-------------------+---------+
# | Col 0                   | Col 1   | Col 2             | Col 3   |
# +=========================+=========+===================+=========+
# | http://ddis.ch/atai/tag | None    | action            | None    |
# +-------------------------+---------+-------------------+---------+
# | http://ddis.ch/atai/tag | None    | alternate_reality | None    |
# +-------------------------+---------+-------------------+---------+
# | http://ddis.ch/atai/tag | None    | boring            | None    |
# +-------------------------+---------+-------------------+---------+
# [['http://ddis.ch/atai/tag', 'None', 'action', 'None'],
#  ['http://ddis.ch/atai/tag', 'None', 'alternate_reality', 'None'],
#  ['http://ddis.ch/atai/tag', 'None', 'boring', 'None'],
#  ['http://ddis.ch/atai/tag', 'None', 'clever', 'None'],
#  ['http://ddis.ch/atai/tag', 'None', 'dramatic', 'None'],
#  ['http://ddis.ch/atai/tag', 'None', 'fantasy', 'None'],
#  ['http://ddis.ch/atai/tag', 'None', 'flashback', 'None'],
#  ['http://ddis.ch/atai/tag', 'None', 'murder', 'None'],
#  ['http://ddis.ch/atai/tag', 'None', 'mystery', 'None'],
#  ['http://ddis.ch/atai/tag', 'None', 'neo_noir', 'None'],
#  ['http://ddis.ch/atai/tag', 'None', 'philosophical', 'None'],
#  ['http://ddis.ch/atai/tag', 'None', 'plot_twist', 'None'],
#  ['http://ddis.ch/atai/tag', 'None', 'psychedelic', 'None'],
#  ['http://ddis.ch/atai/tag', 'None', 'psychological', 'None'],
#  ['http://ddis.ch/atai/tag', 'None', 'sci-fi', 'None'],
#  ['http://ddis.ch/atai/tag', 'None', 'sentimental', 'None'],
#  ['http://ddis.ch/atai/tag', 'None', 'suspenseful', 'None'],
#  ['http://ddis.ch/atai/tag', 'None', 'thought-provoking', 'None'],
#  ['http://ddis.ch/atai/tag', 'None', 'violence', 'None'],
#  ['http://schema.org/description',
#   'node description',
#   '2010 science fiction film directed by Christopher Nolan',
#   'None'],
#  ['http://www.w3.org/2000/01/rdf-schema#label',
#   'node label',
#   'Inception',
#   'None'],
#  ['http://www.wikidata.org/prop/direct/P1040',
#   'film editor',
#   'http://www.wikidata.org/entity/Q1811998',
#   'Lee Smith'],
#  ['http://www.wikidata.org/prop/direct/P136',
#   'genre',
#   'http://www.wikidata.org/entity/Q1200678',
#   'mystery film'],
#  ['http://www.wikidata.org/prop/direct/P136',
#   'genre',
#   'http://www.wikidata.org/entity/Q130232',
#   'drama'],
#  ['http://www.wikidata.org/prop/direct/P136',
#   'genre',
#   'http://www.wikidata.org/entity/Q20656232',
#   'science fiction action film'],
#  ['http://www.wikidata.org/prop/direct/P136',
#   'genre',
#   'http://www.wikidata.org/entity/Q2484376',
#   'thriller film'],
#  ['http://www.wikidata.org/prop/direct/P136',
#   'genre',
#   'http://www.wikidata.org/entity/Q319221',
#   'adventure film'],
#  ['http://www.wikidata.org/prop/direct/P136',
#   'genre',
#   'http://www.wikidata.org/entity/Q471839',
#   'science fiction film'],
#  ['http://www.wikidata.org/prop/direct/P136',
#   'genre',
#   'http://www.wikidata.org/entity/Q496523',
#   'heist film'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q102427',
#   'Academy Award for Best Picture'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q131520',
#   'Academy Award for Best Cinematography'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q277751',
#   'Academy Award for Best Production Design'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q393686',
#   'Academy Award for Best Visual Effects'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q41417',
#   'Academy Award for Best Writing, Original Screenplay'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q488645',
#   'Academy Award for Best Sound Editing'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q488651',
#   'Academy Award for Best Original Score'],
#  ['http://www.wikidata.org/prop/direct/P1411',
#   'nominated for',
#   'http://www.wikidata.org/entity/Q830079',
#   'Academy Award for Best Sound'],
#  ['http://www.wikidata.org/prop/direct/P155',
#   'follows',
#   'http://www.wikidata.org/entity/Q2499084',
#   'Through the Wormhole'],
#  ['http://www.wikidata.org/prop/direct/P1552',
#   'has quality',
#   'http://www.wikidata.org/entity/Q27834579',
#   'title for Hispanic America'],
#  ['http://www.wikidata.org/prop/direct/P1552',
#   'has quality',
#   'http://www.wikidata.org/entity/Q27847754',
#   'title for Spain'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q1225469',
#   'Dileep Rao'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q123351',
#   'Michael Caine'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q173399',
#   'Elliot Page'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q177311',
#   'Joseph Gordon-Levitt'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q18415482',
#   'Tohoru Masamune'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q18720063',
#   'Claire Geare'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q202589',
#   'Cillian Murphy'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q208026',
#   'Tom Gerard De Van Hardy'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q211553',
#   'Ken Watanabe'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q217137',
#   'Pete Postlethwaite'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q2397879',
#   'Taylor Geare'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q269309',
#   'Talulah Riley'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q299317',
#   'Tom Berenger'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q3046377',
#   'Earl Cameron'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q3507348',
#   'Silvie Laguna'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q3560613',
#   'Virgile Bramly'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q3573137',
#   'Yuji Okumoto'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q38111',
#   'Leonardo DiCaprio'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q386249',
#   'Michael Gaston'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q532169',
#   'Lukas Haas'],
#  ['http://www.wikidata.org/prop/direct/P161',
#   'cast member',
#   'http://www.wikidata.org/entity/Q8927',
#   'Marion Cotillard'],
#  ['http://www.wikidata.org/prop/direct/P1657',
#   'MPAA film rating',
#   'http://www.wikidata.org/entity/Q18665339',
#   'PG-13'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q131520',
#   'Academy Award for Best Cinematography'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q393686',
#   'Academy Award for Best Visual Effects'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q488645',
#   'Academy Award for Best Sound Editing'],
#  ['http://www.wikidata.org/prop/direct/P166',
#   'award received',
#   'http://www.wikidata.org/entity/Q830079',
#   'Academy Award for Best Sound'],
#  ['http://www.wikidata.org/prop/direct/P175',
#   'performer',
#   'http://www.wikidata.org/entity/Q76364',
#   'Hans Zimmer'],
#  ['http://www.wikidata.org/prop/direct/P18',
#   'image',
#   'https://commons.wikimedia.org/wiki/File:InceptionCast2July10.jpg',
#   'None'],
#  ['http://www.wikidata.org/prop/direct/P195',
#   'collection',
#   'http://www.wikidata.org/entity/Q188740',
#   'Museum of Modern Art'],
#  ['http://www.wikidata.org/prop/direct/P1981',
#   'FSK film rating',
#   'http://www.wikidata.org/entity/Q20644796',
#   'FSK 12'],
#  ['http://www.wikidata.org/prop/direct/P2061',
#   'aspect ratio',
#   'http://www.wikidata.org/entity/Q24668302',
#   '2.39:1'],
#  ['http://www.wikidata.org/prop/direct/P2142',
#   'box office',
#   '829895144',
#   'None'],
#  ['http://www.wikidata.org/prop/direct/P2515',
#   'costume designer',
#   'http://www.wikidata.org/entity/Q21573201',
#   'Jeffrey Kurland'],
#  ['http://www.wikidata.org/prop/direct/P2554',
#   'production designer',
#   'http://www.wikidata.org/entity/Q570190',
#   'Guy Hendrix Dyas'],
#  ['http://www.wikidata.org/prop/direct/P272',
#   'production company',
#   'http://www.wikidata.org/entity/Q126399',
#   'Warner Bros.'],
#  ['http://www.wikidata.org/prop/direct/P272',
#   'production company',
#   'http://www.wikidata.org/entity/Q621364',
#   'Legendary Pictures'],
#  ['http://www.wikidata.org/prop/direct/P272',
#   'production company',
#   'http://www.wikidata.org/entity/Q984047',
#   'Syncopy Inc.'],
#  ['http://www.wikidata.org/prop/direct/P2747',
#   'Filmiroda rating',
#   'http://www.wikidata.org/entity/Q23830578',
#   'Category III'],
#  ['http://www.wikidata.org/prop/direct/P2758',
#   'CNC film rating (France)',
#   'http://www.wikidata.org/entity/Q23817729',
#   'no age restriction'],
#  ['http://www.wikidata.org/prop/direct/P31',
#   'instance of',
#   'http://www.wikidata.org/entity/Q11424',
#   'film'],
#  ['http://www.wikidata.org/prop/direct/P3156',
#   'Australian Classification',
#   'http://www.wikidata.org/entity/Q26708077',
#   'M'],
#  ['http://www.wikidata.org/prop/direct/P3306',
#   'ICAA rating',
#   'http://www.wikidata.org/entity/Q27253945',
#   'not recommended for children under 12'],
#  ['http://www.wikidata.org/prop/direct/P344',
#   'director of photography',
#   'http://www.wikidata.org/entity/Q460144',
#   'Wally Pfister'],
#  ['http://www.wikidata.org/prop/direct/P345', 'IMDb ID', 'tt1375666', 'None'],
#  ['http://www.wikidata.org/prop/direct/P364',
#   'original language of film or TV show',
#   'http://www.wikidata.org/entity/Q150',
#   'French'],
#  ['http://www.wikidata.org/prop/direct/P364',
#   'original language of film or TV show',
#   'http://www.wikidata.org/entity/Q1860',
#   'English'],
#  ['http://www.wikidata.org/prop/direct/P364',
#   'original language of film or TV show',
#   'http://www.wikidata.org/entity/Q5287',
#   'Japanese'],
#  ['http://www.wikidata.org/prop/direct/P3650',
#   'JMK film rating',
#   'http://www.wikidata.org/entity/Q28732985',
#   'free from 12 years'],
#  ['http://www.wikidata.org/prop/direct/P3803',
#   'original film format',
#   'http://www.wikidata.org/entity/Q226528',
#   '35 mm film'],
#  ['http://www.wikidata.org/prop/direct/P437',
#   'distribution format',
#   'http://www.wikidata.org/entity/Q5294',
#   'DVD'],
#  ['http://www.wikidata.org/prop/direct/P437',
#   'distribution format',
#   'http://www.wikidata.org/entity/Q723685',
#   'video on demand'],
#  ['http://www.wikidata.org/prop/direct/P462',
#   'color',
#   'http://www.wikidata.org/entity/Q22006653',
#   'color'],
#  ['http://www.wikidata.org/prop/direct/P495',
#   'country of origin',
#   'http://www.wikidata.org/entity/Q145',
#   'United Kingdom'],
#  ['http://www.wikidata.org/prop/direct/P495',
#   'country of origin',
#   'http://www.wikidata.org/entity/Q30',
#   'United States of America'],
#  ['http://www.wikidata.org/prop/direct/P5021',
#   'assessment',
#   'http://www.wikidata.org/entity/Q105776216',
#   'reverse Bechdel Test'],
#  ['http://www.wikidata.org/prop/direct/P5021',
#   'assessment',
#   'http://www.wikidata.org/entity/Q4165246',
#   'Bechdel test'],
#  ['http://www.wikidata.org/prop/direct/P527',
#   'has part',
#   'http://www.wikidata.org/entity/Q106956697',
#   'Braaam sound effect'],
#  ['http://www.wikidata.org/prop/direct/P57',
#   'director',
#   'http://www.wikidata.org/entity/Q25191',
#   'Christopher Nolan'],
#  ['http://www.wikidata.org/prop/direct/P577',
#   'publication date',
#   '2010-07-08',
#   'None'],
#  ['http://www.wikidata.org/prop/direct/P58',
#   'screenwriter',
#   'http://www.wikidata.org/entity/Q25191',
#   'Christopher Nolan'],
#  ['http://www.wikidata.org/prop/direct/P5970',
#   'Medierådet rating',
#   'http://www.wikidata.org/entity/Q56887761',
#   'For ages 15 and up'],
#  ['http://www.wikidata.org/prop/direct/P6658',
#   'RCQ classification',
#   'http://www.wikidata.org/entity/Q62365366',
#   'G'],
#  ['http://www.wikidata.org/prop/direct/P750',
#   'distributed by',
#   'http://www.wikidata.org/entity/Q1097348',
#   'InterCom'],
#  ['http://www.wikidata.org/prop/direct/P750',
#   'distributed by',
#   'http://www.wikidata.org/entity/Q80948336',
#   'FandangoNow'],
#  ['http://www.wikidata.org/prop/direct/P750',
#   'distributed by',
#   'http://www.wikidata.org/entity/Q907311',
#   'Netflix'],
#  ['http://www.wikidata.org/prop/direct/P840',
#   'narrative location',
#   'http://www.wikidata.org/entity/Q408',
#   'Australia'],
#  ['http://www.wikidata.org/prop/direct/P840',
#   'narrative location',
#   'http://www.wikidata.org/entity/Q65',
#   'Los Angeles'],
#  ['http://www.wikidata.org/prop/direct/P840',
#   'narrative location',
#   'http://www.wikidata.org/entity/Q90',
#   'Paris'],
#  ['http://www.wikidata.org/prop/direct/P915',
#   'filming location',
#   'http://www.wikidata.org/entity/Q1028',
#   'Morocco'],
#  ['http://www.wikidata.org/prop/direct/P915',
#   'filming location',
#   'http://www.wikidata.org/entity/Q1231271',
#   'Farnborough Airport'],
#  ['http://www.wikidata.org/prop/direct/P915',
#   'filming location',
#   'http://www.wikidata.org/entity/Q126148',
#   'Tangier'],
#  ['http://www.wikidata.org/prop/direct/P915',
#   'filming location',
#   'http://www.wikidata.org/entity/Q1490',
#   'Tokyo'],
#  ['http://www.wikidata.org/prop/direct/P915',
#   'filming location',
#   'http://www.wikidata.org/entity/Q1632912',
#   'Musée Galliera'],
#  ['http://www.wikidata.org/prop/direct/P915',
#   'filming location',
#   'http://www.wikidata.org/entity/Q17',
#   'Japan'],
#  ['http://www.wikidata.org/prop/direct/P915',
#   'filming location',
#   'http://www.wikidata.org/entity/Q193196',
#   'University College London'],
#  ['http://www.wikidata.org/prop/direct/P915',
#   'filming location',
#   'http://www.wikidata.org/entity/Q1951',
#   'Alberta'],
#  ['http://www.wikidata.org/prop/direct/P915',
#   'filming location',
#   'http://www.wikidata.org/entity/Q290355',
#   'pont de Bir-Hakeim'],
#  ['http://www.wikidata.org/prop/direct/P915',
#   'filming location',
#   'http://www.wikidata.org/entity/Q387047',
#   'Malibu'],
#  ['http://www.wikidata.org/prop/direct/P915',
#   'filming location',
#   'http://www.wikidata.org/entity/Q5153249',
#   'Commodore Schuyler F. Heim Bridge'],
#  ['http://www.wikidata.org/prop/direct/P915',
#   'filming location',
#   'http://www.wikidata.org/entity/Q5472723',
#   'Fortress Mountain Resort'],
#  ['http://www.wikidata.org/prop/direct/P915',
#   'filming location',
#   'http://www.wikidata.org/entity/Q7275217',
#   'RAF Cardington'],
#  ['http://www.wikidata.org/prop/direct/P915',
#   'filming location',
#   'http://www.wikidata.org/entity/Q90',
#   'Paris'],
#  ['http://www.wikidata.org/prop/direct/P915',
#   'filming location',
#   'http://www.wikidata.org/entity/Q99',
#   'California'],
#  ['http://www.wikidata.org/prop/direct/P921',
#   'main subject',
#   'http://www.wikidata.org/entity/Q4425624',
#   'dream world'],
#  ['http://www.wikidata.org/prop/direct/P921',
#   'main subject',
#   'http://www.wikidata.org/entity/Q544830',
#   'telepresence']]
